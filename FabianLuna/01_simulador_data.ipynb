# %% [markdown]
# # Librerías

# %%
# pip install geopy

# %%
# pip install meteostat

# %%
import json
import time
import uuid
import random
from datetime import datetime, timedelta
import pytz
from geopy.geocoders import Nominatim
from meteostat import Point, Hourly
# employees = {i: (f"{i+1}", f"{i+101}") for i in range(100)}

# %%
# Definir las coordenadas aproximadas de Medellín
lat_range = (6.217, 6.317)  # Latitud de Medellín
lon_range = (-75.567, -75.467)  # Longitud de Medellín

# Inicializar el geolocalizador
geolocator = Nominatim(user_agent="medellin_locator")

# %% [markdown]
# # Obtención de datos

# %%
# Cargar puntos de venta válidos desde el archivo JSON
with open('valid_points.json', 'r') as file:
    points_of_sale = json.load(file)

# Generar 200 empleados, 2 por cada punto de venta
employees = {i: (f"Employee_{i*2+1}", f"Employee_{i*2+2}") for i in range(100)}

# Inicializar el geolocalizador
geolocator = Nominatim(user_agent="medellin_locator")

# Función para obtener la temperatura actual
def get_current_temperature(latitude, longitude):
    location = Point(latitude, longitude)
    start = datetime.now() - timedelta(hours=1)
    end = datetime.now()
    data = Hourly(location, start, end)
    data = data.fetch()
    temperature = data['temp'].mean() if not data.empty else 20  # Usar 20 como valor predeterminado si no hay datos
    return round(temperature, 1)

# Generar cantidad de productos en función de la temperatura
def generate_quantity_products(temperature):
    # Normalizar la temperatura entre un rango de 0 y 1
    temp_min, temp_max = 18, 24  # Rango de temperaturas en °C
    normalized_temp = (temperature - temp_min) / (temp_max - temp_min)
    
    # Generar la cantidad de productos basada en la temperatura normalizada
    min_quantity, max_quantity = 1, 50
    mean_quantity = normalized_temp * (max_quantity - min_quantity) + min_quantity
    
    # Añadir variabilidad a la cantidad de productos
    quantity = int(random.gauss(mean_quantity,10))  # Usar una desviación estándar de 10
    
    # Asegurar que la cantidad esté dentro del rango permitido
    return max(min(quantity, max_quantity), min_quantity)

# Generar datos simulados
def generate_event(pos_index):
    pos = points_of_sale[pos_index]
    worker = employees[pos_index]
    date_now = datetime.now(pytz.timezone('America/Bogota'))
    temperature = get_current_temperature(pos["latitude"], pos["longitude"])
    quantity_products = generate_quantity_products(temperature)
    
    event = {
        "latitude": pos["latitude"],
        "longitude": pos["longitude"],
        "date": date_now.strftime("%d/%m/%Y %H:%M:%S"),
        "customer_id": random.randint(1000, 2000),
        "employee_id": worker[0] if date_now.weekday() < 5 else worker[1],  # Lunes a Viernes / Fines de Semana
        "quantity_products": quantity_products,
        "order_id": str(uuid.uuid4()),
        "commune": pos["commune"],
        "neighborhood": pos["neighborhood"],
        "partition_date": date_now.strftime("%d%m%Y"),
        "event_date": date_now.strftime("%d/%m/%Y %H:%M:%S"),
        "event_day": date_now.day,
        "event_hour": date_now.hour,
        "event_minute": date_now.minute,
        "event_month": date_now.month,
        "event_second": date_now.second,
        "event_year": date_now.year,
        "current_temperature": temperature
    }
    return event


# Enviar los datos
def send_data(s, conn, data):
    conn.sendall(json.dumps(data).encode() + b'\n')
    print("Enviado:", data)

# %% [markdown]
# # Socket

# %%
import socket

# %%
# Socket
def servidor():
    
    host = 'localhost'  # Nombre del host o dirección IP
    port = 2222  # Puerto en el que escucha el servidor

    s = socket.socket()
    s.bind((host, port))
    s.listen(1)
    print(f"Listening on {host}:{port}")
    
    conn, addr = s.accept()
    print(f"Connected from {addr}")
    
    try:
        while True:
            event = generate_event(random.randint(0, 99))
            # Esperar 30 segundos antes de generar el siguiente evento
            send_data(s, conn, event)
            # Guardado en un archivo JSON
            with open('simulated_data_02.json', 'a') as file:
                file.write(json.dumps(event) + "\n")
            
            time.sleep(1)
            
    except KeyboardInterrupt:
        print("Stopping the connection ...")
        conn.close()
        s.close()
        print("Connection stopped.")
    
    except BrokenPipeError:
        print("The connection has been closed.")
        conn.close()
        s.close()

if __name__ == "__main__":
    servidor()
# Out:
# Listening on localhost:2222
# Connected from ('127.0.0.1', 47086)
# Enviado: {'latitude': 6.233554, 'longitude': -75.565071, 'date': '17/06/2024 17:42:09', 'customer_id': 1580, 'employee_id': 'Employee_129', 'quantity_products': 36, 'order_id': 'fe60082e-fdb9-487e-a093-f6f63f4e8719', 'commune': 'Comuna 10 - La Candelaria', 'neighborhood': 'Barrio San Diego', 'partition_date': '17062024', 'event_date': '17/06/2024 17:42:09', 'event_day': 17, 'event_hour': 17, 'event_minute': 42, 'event_month': 6, 'event_second': 9, 'event_year': 2024, 'current_temperature': 24.0}
# Enviado: {'latitude': 6.226864, 'longitude': -75.52891, 'date': '17/06/2024 17:42:11', 'customer_id': 1353, 'employee_id': 'Employee_65', 'quantity_products': 27, 'order_id': 'f0744cfa-2cfd-493d-9d82-0903023ac36a', 'commune': 'Comuna 9 - Buenos Aires', 'neighborhood': 'Ocho de Marzo', 'partition_date': '17062024', 'event_date': '17/06/2024 17:42:11', 'event_day': 17, 'event_hour': 17, 'event_minute': 42, 'event_month': 6, 'event_second': 11, 'event_year': 2024, 'current_temperature': 24.0}
# Enviado: {'latitude': 6.288678, 'longitude': -75.556225, 'date': '17/06/2024 17:42:13', 'customer_id': 1451, 'employee_id': 'Employee_135', 'quantity_products': 39, 'order_id': '160655a4-f0fa-4a29-ab15-bb3983137fa6', 'commune': 'Comuna 4 - Aranjuez', 'neighborhood': 'Berlin', 'partition_date': '17062024', 'event_date': '17/06/2024 17:42:13', 'event_day': 17, 'event_hour': 17, 'event_minute': 42, 'event_month': 6, 'event_second': 13, 'event_year': 2024, 'current_temperature': 24.0}
# Enviado: {'latitude': 6.231588, 'longitude': -75.541907, 'date': '17/06/2024 17:42:14', 'customer_id': 1695, 'employee_id': 'Employee_105', 'quantity_products': 50, 'order_id': '30b73811-1a89-4a91-bb5f-2bdd0b1c6715', 'commune': 'Comuna 9 - Buenos Aires', 'neighborhood': 'Bomboná No. 2', 'partition_date': '17062024', 'event_date': '17/06/2024 17:42:14', 'event_day': 17, 'event_hour': 17, 'event_minute': 42, 'event_month': 6, 'event_second': 14, 'event_year': 2024, 'current_temperature': 24.0}
# Enviado: {'latitude': 6.241721, 'longitude': -75.544554, 'date': '17/06/2024 17:42:15', 'customer_id': 1663, 'employee_id': 'Employee_83', 'quantity_products': 50, 'order_id': 'a826f8e9-ce18-4dc1-a9d3-e0eb4a57d473', 'commune': 'Comuna 8 - Villa Hermosa', 'neighborhood': 'La Libertad', 'partition_date': '17062024', 'event_date': '17/06/2024 17:42:15', 'event_day': 17, 'event_hour': 17, 'event_minute': 42, 'event_month': 6, 'event_second': 15, 'event_year': 2024, 'current_temperature': 24.0}
# Enviado: {'latitude': 6.23618, 'longitude': -75.557692, 'date': '17/06/2024 17:42:16', 'customer_id': 1284, 'employee_id': 'Employee_169', 'quantity_products': 50, 'order_id': '3a577b5b-c0a2-476b-985a-6b860c9fc419', 'commune': 'Comuna 9 - Buenos Aires', 'neighborhood': 'Gerona', 'partition_date': '17062024', 'event_date': '17/06/2024 17:42:16', 'event_day': 17, 'event_hour': 17, 'event_minute': 42, 'event_month': 6, 'event_second': 16, 'event_year': 2024, 'current_temperature': 24.0}
# Enviado: {'latitude': 6.255721, 'longitude': -75.560525, 'date': '17/06/2024 17:42:17', 'customer_id': 1876, 'employee_id': 'Employee_199', 'quantity_products': 41, 'order_id': '7a5327e0-f67c-46c0-a0f0-1dff50cb70ec', 'commune': 'Comuna 8 - Villa Hermosa', 'neighborhood': 'San Miguel', 'partition_date': '17062024', 'event_date': '17/06/2024 17:42:17', 'event_day': 17, 'event_hour': 17, 'event_minute': 42, 'event_month': 6, 'event_second': 17, 'event_year': 2024, 'current_temperature': 24.0}
# Enviado: {'latitude': 6.233554, 'longitude': -75.565071, 'date': '17/06/2024 17:42:18', 'customer_id': 1347, 'employee_id': 'Employee_129', 'quantity_products': 50, 'order_id': '69f8f4e5-ca3b-4566-957e-f563d830705e', 'commune': 'Comuna 10 - La Candelaria', 'neighborhood': 'Barrio San Diego', 'partition_date': '17062024', 'event_date': '17/06/2024 17:42:18', 'event_day': 17, 'event_hour': 17, 'event_minute': 42, 'event_month': 6, 'event_second': 18, 'event_year': 2024, 'current_temperature': 24.0}
# Enviado: {'latitude': 6.23618, 'longitude': -75.557692, 'date': '17/06/2024 17:42:19', 'customer_id': 1017, 'employee_id': 'Employee_169', 'quantity_products': 50, 'order_id': '902dc6ea-5bab-49ac-b581-e16f06803f1c', 'commune': 'Comuna 9 - Buenos Aires', 'neighborhood': 'Gerona', 'partition_date': '17062024', 'event_date': '17/06/2024 17:42:19', 'event_day': 17, 'event_hour': 17, 'event_minute': 42, 'event_month': 6, 'event_second': 19, 'event_year': 2024, 'current_temperature': 24.0}
# Enviado: {'latitude': 6.226864, 'longitude': -75.52891, 'date': '17/06/2024 17:42:20', 'customer_id': 1697, 'employee_id': 'Employee_65', 'quantity_products': 50, 'order_id': '0499d277-9797-49fd-8560-d9f16e5b5cf6', 'commune': 'Comuna 9 - Buenos Aires', 'neighborhood': 'Ocho de Marzo', 'partition_date': '17062024', 'event_date': '17/06/2024 17:42:20', 'event_day': 17, 'event_hour': 17, 'event_minute': 42, 'event_month': 6, 'event_second': 20, 'event_year': 2024, 'current_temperature': 24.0}
# Enviado: {'latitude': 6.241721, 'longitude': -75.544554, 'date': '17/06/2024 17:42:21', 'customer_id': 1793, 'employee_id': 'Employee_83', 'quantity_products': 50, 'order_id': '8d46d7f9-e6bb-4fa0-898f-0f9e140a48d1', 'commune': 'Comuna 8 - Villa Hermosa', 'neighborhood': 'La Libertad', 'partition_date': '17062024', 'event_date': '17/06/2024 17:42:21', 'event_day': 17, 'event_hour': 17, 'event_minute': 42, 'event_month': 6, 'event_second': 21, 'event_year': 2024, 'current_temperature': 24.0}
# Enviado: {'latitude': 6.237547, 'longitude': -75.536549, 'date': '17/06/2024 17:42:22', 'customer_id': 1064, 'employee_id': 'Employee_23', 'quantity_products': 45, 'order_id': '29e9bbee-87dd-4537-b875-4913a7927e69', 'commune': 'Comuna 8 - Villa Hermosa', 'neighborhood': 'San Antonio', 'partition_date': '17062024', 'event_date': '17/06/2024 17:42:22', 'event_day': 17, 'event_hour': 17, 'event_minute': 42, 'event_month': 6, 'event_second': 22, 'event_year': 2024, 'current_temperature': 24.0}
# Enviado: {'latitude': 6.269597, 'longitude': -75.531581, 'date': '17/06/2024 17:42:23', 'customer_id': 1801, 'employee_id': 'Employee_17', 'quantity_products': 45, 'order_id': 'bd67b4d7-dc3f-459f-ba84-3770914c27e6', 'commune': 'Comuna 3 - Manrique', 'neighborhood': 'La Cruz', 'partition_date': '17062024', 'event_date': '17/06/2024 17:42:23', 'event_day': 17, 'event_hour': 17, 'event_minute': 42, 'event_month': 6, 'event_second': 23, 'event_year': 2024, 'current_temperature': 24.0}
# Enviado: {'latitude': 6.295457, 'longitude': -75.557531, 'date': '17/06/2024 17:42:24', 'customer_id': 1643, 'employee_id': 'Employee_127', 'quantity_products': 48, 'order_id': '34915743-657e-4868-87bd-7e57c215d63d', 'commune': 'Comuna 2 - Santa Cruz', 'neighborhood': 'Santa Cruz', 'partition_date': '17062024', 'event_date': '17/06/2024 17:42:24', 'event_day': 17, 'event_hour': 17, 'event_minute': 42, 'event_month': 6, 'event_second': 24, 'event_year': 2024, 'current_temperature': 24.0}
# Enviado: {'latitude': 6.299064, 'longitude': -75.545337, 'date': '17/06/2024 17:42:25', 'customer_id': 1965, 'employee_id': 'Employee_13', 'quantity_products': 50, 'order_id': 'b4f318c0-40ef-45a7-aa49-296b3b7b7430', 'commune': 'Comuna 1 - Popular', 'neighborhood': 'Santo Domingo Savio No.1', 'partition_date': '17062024', 'event_date': '17/06/2024 17:42:25', 'event_day': 17, 'event_hour': 17, 'event_minute': 42, 'event_month': 6, 'event_second': 25, 'event_year': 2024, 'current_temperature': 24.0}
# Enviado: {'latitude': 6.298354, 'longitude': -75.564556, 'date': '17/06/2024 17:42:26', 'customer_id': 1454, 'employee_id': 'Employee_71', 'quantity_products': 38, 'order_id': '5e0bd568-5715-46c9-8e30-f9a42d58996a', 'commune': 'Comuna 5 - Castilla', 'neighborhood': 'Villa Niza', 'partition_date': '17062024', 'event_date': '17/06/2024 17:42:26', 'event_day': 17, 'event_hour': 17, 'event_minute': 42, 'event_month': 6, 'event_second': 26, 'event_year': 2024, 'current_temperature': 24.0}
# Enviado: {'latitude': 6.233572, 'longitude': -75.551487, 'date': '17/06/2024 17:42:27', 'customer_id': 1708, 'employee_id': 'Employee_145', 'quantity_products': 49, 'order_id': '06da1456-3ddf-443c-ba91-8748d9e47004', 'commune': 'Comuna 9 - Buenos Aires', 'neighborhood': 'Cataluña', 'partition_date': '17062024', 'event_date': '17/06/2024 17:42:27', 'event_day': 17, 'event_hour': 17, 'event_minute': 42, 'event_month': 6, 'event_second': 27, 'event_year': 2024, 'current_temperature': 24.0}
# Enviado: {'latitude': 6.237547, 'longitude': -75.536549, 'date': '17/06/2024 17:42:28', 'customer_id': 1257, 'employee_id': 'Employee_23', 'quantity_products': 50, 'order_id': '4f54ad75-2cf5-4771-8ba4-3a625308df65', 'commune': 'Comuna 8 - Villa Hermosa', 'neighborhood': 'San Antonio', 'partition_date': '17062024', 'event_date': '17/06/2024 17:42:28', 'event_day': 17, 'event_hour': 17, 'event_minute': 42, 'event_month': 6, 'event_second': 28, 'event_year': 2024, 'current_temperature': 24.0}
# Enviado: {'latitude': 6.295931, 'longitude': -75.560472, 'date': '17/06/2024 17:42:29', 'customer_id': 1551, 'employee_id': 'Employee_133', 'quantity_products': 41, 'order_id': '1fab1f47-2ec2-482e-96e4-920576b04e72', 'commune': 'Comuna 5 - Castilla', 'neighborhood': 'Villa Niza', 'partition_date': '17062024', 'event_date': '17/06/2024 17:42:29', 'event_day': 17, 'event_hour': 17, 'event_minute': 42, 'event_month': 6, 'event_second': 29, 'event_year': 2024, 'current_temperature': 24.0}
# Enviado: {'latitude': 6.251305, 'longitude': -75.539935, 'date': '17/06/2024 17:42:30', 'customer_id': 1702, 'employee_id': 'Employee_95', 'quantity_products': 44, 'order_id': '6e9b8e7b-5adb-43a4-ac51-839c62b7ca8f', 'commune': 'Comuna 8 - Villa Hermosa', 'neighborhood': 'Llanaditas', 'partition_date': '17062024', 'event_date': '17/06/2024 17:42:30', 'event_day': 17, 'event_hour': 17, 'event_minute': 42, 'event_month': 6, 'event_second': 30, 'event_year': 2024, 'current_temperature': 24.0}
# Enviado: {'latitude': 6.220574, 'longitude': -75.542085, 'date': '17/06/2024 17:42:31', 'customer_id': 1131, 'employee_id': 'Employee_119', 'quantity_products': 35, 'order_id': 'b34d8ac8-1d7d-4e2b-bedb-d580d7686d4b', 'commune': 'Comuna 9 - Buenos Aires', 'neighborhood': 'Bomboná No. 2', 'partition_date': '17062024', 'event_date': '17/06/2024 17:42:31', 'event_day': 17, 'event_hour': 17, 'event_minute': 42, 'event_month': 6, 'event_second': 31, 'event_year': 2024, 'current_temperature': 24.0}
# Enviado: {'latitude': 6.304733, 'longitude': -75.563183, 'date': '17/06/2024 17:42:32', 'customer_id': 1767, 'employee_id': 'Employee_55', 'quantity_products': 50, 'order_id': 'b4efd1df-d82c-45b4-aa3d-4205aafe4990', 'commune': 'Comuna 5 - Castilla', 'neighborhood': 'Boyacá', 'partition_date': '17062024', 'event_date': '17/06/2024 17:42:32', 'event_day': 17, 'event_hour': 17, 'event_minute': 42, 'event_month': 6, 'event_second': 32, 'event_year': 2024, 'current_temperature': 24.0}
# Enviado: {'latitude': 6.269597, 'longitude': -75.531581, 'date': '17/06/2024 17:42:33', 'customer_id': 1341, 'employee_id': 'Employee_17', 'quantity_products': 45, 'order_id': 'c8c36914-9def-4753-93a7-3b6c37bcd0e2', 'commune': 'Comuna 3 - Manrique', 'neighborhood': 'La Cruz', 'partition_date': '17062024', 'event_date': '17/06/2024 17:42:33', 'event_day': 17, 'event_hour': 17, 'event_minute': 42, 'event_month': 6, 'event_second': 33, 'event_year': 2024, 'current_temperature': 24.0}
# Enviado: {'latitude': 6.2684, 'longitude': -75.552571, 'date': '17/06/2024 17:42:34', 'customer_id': 1972, 'employee_id': 'Employee_137', 'quantity_products': 46, 'order_id': 'efdb33c1-fe31-440a-9ec5-e845af1e583a', 'commune': 'Comuna 3 - Manrique', 'neighborhood': 'El Pomar', 'partition_date': '17062024', 'event_date': '17/06/2024 17:42:34', 'event_day': 17, 'event_hour': 17, 'event_minute': 42, 'event_month': 6, 'event_second': 34, 'event_year': 2024, 'current_temperature': 24.0}
# Enviado: {'latitude': 6.300326, 'longitude': -75.551767, 'date': '17/06/2024 17:42:35', 'customer_id': 1103, 'employee_id': 'Employee_33', 'quantity_products': 48, 'order_id': 'c2598e41-dce6-4534-94d1-e1ce31f219ba', 'commune': 'Comuna 2 - Santa Cruz', 'neighborhood': 'La Isla', 'partition_date': '17062024', 'event_date': '17/06/2024 17:42:35', 'event_day': 17, 'event_hour': 17, 'event_minute': 42, 'event_month': 6, 'event_second': 35, 'event_year': 2024, 'current_temperature': 24.0}
# Enviado: {'latitude': 6.228642, 'longitude': -75.529782, 'date': '17/06/2024 17:42:36', 'customer_id': 1750, 'employee_id': 'Employee_31', 'quantity_products': 46, 'order_id': '6ddf5148-78ea-4615-bccb-3ace3b1c38b8', 'commune': 'Comuna 9 - Buenos Aires', 'neighborhood': 'Ocho de Marzo', 'partition_date': '17062024', 'event_date': '17/06/2024 17:42:36', 'event_day': 17, 'event_hour': 17, 'event_minute': 42, 'event_month': 6, 'event_second': 36, 'event_year': 2024, 'current_temperature': 24.0}
# Enviado: {'latitude': 6.251305, 'longitude': -75.539935, 'date': '17/06/2024 17:42:37', 'customer_id': 1286, 'employee_id': 'Employee_95', 'quantity_products': 44, 'order_id': '4a633588-02ce-47d1-ac1c-8154438b7346', 'commune': 'Comuna 8 - Villa Hermosa', 'neighborhood': 'Llanaditas', 'partition_date': '17062024', 'event_date': '17/06/2024 17:42:37', 'event_day': 17, 'event_hour': 17, 'event_minute': 42, 'event_month': 6, 'event_second': 37, 'event_year': 2024, 'current_temperature': 24.0}
# Enviado: {'latitude': 6.255342, 'longitude': -75.555875, 'date': '17/06/2024 17:42:38', 'customer_id': 1736, 'employee_id': 'Employee_157', 'quantity_products': 50, 'order_id': '4ea4ceaa-f8a5-4109-b6ff-8e61dc507526', 'commune': 'Comuna 8 - Villa Hermosa', 'neighborhood': 'San Miguel', 'partition_date': '17062024', 'event_date': '17/06/2024 17:42:38', 'event_day': 17, 'event_hour': 17, 'event_minute': 42, 'event_month': 6, 'event_second': 38, 'event_year': 2024, 'current_temperature': 24.0}
# Enviado: {'latitude': 6.218558, 'longitude': -75.560038, 'date': '17/06/2024 17:42:39', 'customer_id': 1379, 'employee_id': 'Employee_187', 'quantity_products': 31, 'order_id': '710aa2bf-214c-4be3-9ff2-9c3cb0e3a038', 'commune': 'Comuna 9 - Buenos Aires', 'neighborhood': 'La Asomadera No. 3', 'partition_date': '17062024', 'event_date': '17/06/2024 17:42:39', 'event_day': 17, 'event_hour': 17, 'event_minute': 42, 'event_month': 6, 'event_second': 39, 'event_year': 2024, 'current_temperature': 24.0}
# Enviado: {'latitude': 6.254946, 'longitude': -75.558221, 'date': '17/06/2024 17:42:40', 'customer_id': 1354, 'employee_id': 'Employee_147', 'quantity_products': 37, 'order_id': '28923d3a-0ac2-4af6-9133-181802fe42bc', 'commune': 'Comuna 8 - Villa Hermosa', 'neighborhood': 'San Miguel', 'partition_date': '17062024', 'event_date': '17/06/2024 17:42:40', 'event_day': 17, 'event_hour': 17, 'event_minute': 42, 'event_month': 6, 'event_second': 40, 'event_year': 2024, 'current_temperature': 24.0}
# Enviado: {'latitude': 6.240851, 'longitude': -75.564423, 'date': '17/06/2024 17:42:41', 'customer_id': 1030, 'employee_id': 'Employee_91', 'quantity_products': 50, 'order_id': 'caec0d87-af8c-4eb4-ab52-51be182eeb24', 'commune': 'Comuna 10 - La Candelaria', 'neighborhood': 'Bomboná No. 1', 'partition_date': '17062024', 'event_date': '17/06/2024 17:42:41', 'event_day': 17, 'event_hour': 17, 'event_minute': 42, 'event_month': 6, 'event_second': 41, 'event_year': 2024, 'current_temperature': 24.0}
# Enviado: {'latitude': 6.236241, 'longitude': -75.566549, 'date': '17/06/2024 17:42:42', 'customer_id': 1295, 'employee_id': 'Employee_163', 'quantity_products': 50, 'order_id': '31db7e85-a5b1-49e8-b8cb-5a0cf7d11e20', 'commune': 'Comuna 10 - La Candelaria', 'neighborhood': 'Barrio San Diego', 'partition_date': '17062024', 'event_date': '17/06/2024 17:42:42', 'event_day': 17, 'event_hour': 17, 'event_minute': 42, 'event_month': 6, 'event_second': 42, 'event_year': 2024, 'current_temperature': 24.0}
# Enviado: {'latitude': 6.267149, 'longitude': -75.539398, 'date': '17/06/2024 17:42:43', 'customer_id': 1002, 'employee_id': 'Employee_97', 'quantity_products': 50, 'order_id': 'c34f0953-24e2-4652-b0d5-9a9c1cf4f900', 'commune': 'Comuna 3 - Manrique', 'neighborhood': 'Versalles No. 2', 'partition_date': '17062024', 'event_date': '17/06/2024 17:42:43', 'event_day': 17, 'event_hour': 17, 'event_minute': 42, 'event_month': 6, 'event_second': 43, 'event_year': 2024, 'current_temperature': 24.0}
# Enviado: {'latitude': 6.263214, 'longitude': -75.565651, 'date': '17/06/2024 17:42:44', 'customer_id': 1870, 'employee_id': 'Employee_117', 'quantity_products': 38, 'order_id': '8f069936-1ae6-4602-80c5-3f6e93570724', 'commune': 'Comuna 10 - La Candelaria', 'neighborhood': 'Prado', 'partition_date': '17062024', 'event_date': '17/06/2024 17:42:44', 'event_day': 17, 'event_hour': 17, 'event_minute': 42, 'event_month': 6, 'event_second': 44, 'event_year': 2024, 'current_temperature': 24.0}
# Enviado: {'latitude': 6.228153, 'longitude': -75.52915, 'date': '17/06/2024 17:42:45', 'customer_id': 1732, 'employee_id': 'Employee_185', 'quantity_products': 43, 'order_id': '4a48c622-1188-4edd-92be-95832f159fe3', 'commune': 'Comuna 9 - Buenos Aires', 'neighborhood': 'Ocho de Marzo', 'partition_date': '17062024', 'event_date': '17/06/2024 17:42:45', 'event_day': 17, 'event_hour': 17, 'event_minute': 42, 'event_month': 6, 'event_second': 45, 'event_year': 2024, 'current_temperature': 24.0}
# Enviado: {'latitude': 6.252831, 'longitude': -75.565694, 'date': '17/06/2024 17:42:46', 'customer_id': 1138, 'employee_id': 'Employee_11', 'quantity_products': 50, 'order_id': '88113fad-437f-4ee6-92c4-32c3fdd091d2', 'commune': 'Comuna 10 - La Candelaria', 'neighborhood': 'Villa Nueva', 'partition_date': '17062024', 'event_date': '17/06/2024 17:42:46', 'event_day': 17, 'event_hour': 17, 'event_minute': 42, 'event_month': 6, 'event_second': 46, 'event_year': 2024, 'current_temperature': 24.0}
# Enviado: {'latitude': 6.299954, 'longitude': -75.559406, 'date': '17/06/2024 17:42:47', 'customer_id': 1448, 'employee_id': 'Employee_141', 'quantity_products': 50, 'order_id': '3d0b3d29-6b00-438a-b895-d913878bec41', 'commune': 'Comuna 5 - Castilla', 'neighborhood': 'Héctor Abad Gómez', 'partition_date': '17062024', 'event_date': '17/06/2024 17:42:47', 'event_day': 17, 'event_hour': 17, 'event_minute': 42, 'event_month': 6, 'event_second': 47, 'event_year': 2024, 'current_temperature': 24.0}
# Enviado: {'latitude': 6.297461, 'longitude': -75.557846, 'date': '17/06/2024 17:42:48', 'customer_id': 1776, 'employee_id': 'Employee_3', 'quantity_products': 50, 'order_id': 'ddc7750d-63b6-4cf9-8856-e8e1f55b1423', 'commune': 'Comuna 2 - Santa Cruz', 'neighborhood': 'Santa Cruz', 'partition_date': '17062024', 'event_date': '17/06/2024 17:42:48', 'event_day': 17, 'event_hour': 17, 'event_minute': 42, 'event_month': 6, 'event_second': 48, 'event_year': 2024, 'current_temperature': 24.0}
# Enviado: {'latitude': 6.272454, 'longitude': -75.55848, 'date': '17/06/2024 17:42:49', 'customer_id': 1625, 'employee_id': 'Employee_87', 'quantity_products': 48, 'order_id': '0037c797-6240-4c64-b270-974c994ea401', 'commune': 'Comuna 4 - Aranjuez', 'neighborhood': 'Brasilia', 'partition_date': '17062024', 'event_date': '17/06/2024 17:42:49', 'event_day': 17, 'event_hour': 17, 'event_minute': 42, 'event_month': 6, 'event_second': 49, 'event_year': 2024, 'current_temperature': 24.0}
# Enviado: {'latitude': 6.226864, 'longitude': -75.52891, 'date': '17/06/2024 17:42:50', 'customer_id': 1414, 'employee_id': 'Employee_65', 'quantity_products': 44, 'order_id': '50c97b1a-bc6e-4151-983d-51bedfa384b6', 'commune': 'Comuna 9 - Buenos Aires', 'neighborhood': 'Ocho de Marzo', 'partition_date': '17062024', 'event_date': '17/06/2024 17:42:50', 'event_day': 17, 'event_hour': 17, 'event_minute': 42, 'event_month': 6, 'event_second': 50, 'event_year': 2024, 'current_temperature': 24.0}
# Enviado: {'latitude': 6.233505, 'longitude': -75.539321, 'date': '17/06/2024 17:42:51', 'customer_id': 1632, 'employee_id': 'Employee_103', 'quantity_products': 28, 'order_id': 'c3c1f1d9-c5d1-43fc-ab83-8c8d05b94ff8', 'commune': 'Comuna 8 - Villa Hermosa', 'neighborhood': 'Villa Tina', 'partition_date': '17062024', 'event_date': '17/06/2024 17:42:51', 'event_day': 17, 'event_hour': 17, 'event_minute': 42, 'event_month': 6, 'event_second': 51, 'event_year': 2024, 'current_temperature': 24.0}
# Enviado: {'latitude': 6.263089, 'longitude': -75.562475, 'date': '17/06/2024 17:42:52', 'customer_id': 1976, 'employee_id': 'Employee_69', 'quantity_products': 50, 'order_id': '05e129cf-795c-4c62-ad9f-4f3d07312076', 'commune': 'Comuna 10 - La Candelaria', 'neighborhood': 'Prado', 'partition_date': '17062024', 'event_date': '17/06/2024 17:42:52', 'event_day': 17, 'event_hour': 17, 'event_minute': 42, 'event_month': 6, 'event_second': 52, 'event_year': 2024, 'current_temperature': 24.0}
# Enviado: {'latitude': 6.22135, 'longitude': -75.548236, 'date': '17/06/2024 17:42:53', 'customer_id': 1770, 'employee_id': 'Employee_101', 'quantity_products': 43, 'order_id': '1c7d5a9a-f8ef-4da3-aaba-3ae7b8615aab', 'commune': 'Comuna 9 - Buenos Aires', 'neighborhood': 'La Asomadera No. 3', 'partition_date': '17062024', 'event_date': '17/06/2024 17:42:53', 'event_day': 17, 'event_hour': 17, 'event_minute': 42, 'event_month': 6, 'event_second': 53, 'event_year': 2024, 'current_temperature': 24.0}
# Enviado: {'latitude': 6.256553, 'longitude': -75.552019, 'date': '17/06/2024 17:42:54', 'customer_id': 1028, 'employee_id': 'Employee_7', 'quantity_products': 50, 'order_id': 'cd4543c5-da2b-408b-8532-ce7df36c540c', 'commune': 'Comuna 8 - Villa Hermosa', 'neighborhood': 'Villa Hermosa', 'partition_date': '17062024', 'event_date': '17/06/2024 17:42:54', 'event_day': 17, 'event_hour': 17, 'event_minute': 42, 'event_month': 6, 'event_second': 54, 'event_year': 2024, 'current_temperature': 24.0}
# Enviado: {'latitude': 6.22135, 'longitude': -75.548236, 'date': '17/06/2024 17:42:55', 'customer_id': 1447, 'employee_id': 'Employee_101', 'quantity_products': 39, 'order_id': '3125dd59-007a-43e5-8ee1-f8adf5d3511d', 'commune': 'Comuna 9 - Buenos Aires', 'neighborhood': 'La Asomadera No. 3', 'partition_date': '17062024', 'event_date': '17/06/2024 17:42:55', 'event_day': 17, 'event_hour': 17, 'event_minute': 42, 'event_month': 6, 'event_second': 55, 'event_year': 2024, 'current_temperature': 24.0}
# Enviado: {'latitude': 6.230978, 'longitude': -75.533582, 'date': '17/06/2024 17:42:56', 'customer_id': 1873, 'employee_id': 'Employee_9', 'quantity_products': 50, 'order_id': 'e76c9f84-1dc9-43ed-ac9d-a854aa0c4c5e', 'commune': 'Comuna 9 - Buenos Aires', 'neighborhood': 'Barrios de Jesús', 'partition_date': '17062024', 'event_date': '17/06/2024 17:42:56', 'event_day': 17, 'event_hour': 17, 'event_minute': 42, 'event_month': 6, 'event_second': 56, 'event_year': 2024, 'current_temperature': 24.0}
# Enviado: {'latitude': 6.229471, 'longitude': -75.556631, 'date': '17/06/2024 17:42:57', 'customer_id': 1680, 'employee_id': 'Employee_113', 'quantity_products': 50, 'order_id': '642c6559-1f51-4e78-b4a4-1ab1781fad92', 'commune': 'Comuna 9 - Buenos Aires', 'neighborhood': 'Loreto', 'partition_date': '17062024', 'event_date': '17/06/2024 17:42:57', 'event_day': 17, 'event_hour': 17, 'event_minute': 42, 'event_month': 6, 'event_second': 57, 'event_year': 2024, 'current_temperature': 24.0}
# Enviado: {'latitude': 6.250895, 'longitude': -75.564412, 'date': '17/06/2024 17:42:58', 'customer_id': 1602, 'employee_id': 'Employee_193', 'quantity_products': 50, 'order_id': '4267aab3-610e-4393-9ce5-1e86607ff20d', 'commune': 'Comuna 10 - La Candelaria', 'neighborhood': 'La Candelaria', 'partition_date': '17062024', 'event_date': '17/06/2024 17:42:58', 'event_day': 17, 'event_hour': 17, 'event_minute': 42, 'event_month': 6, 'event_second': 58, 'event_year': 2024, 'current_temperature': 24.0}
# Enviado: {'latitude': 6.252831, 'longitude': -75.565694, 'date': '17/06/2024 17:42:59', 'customer_id': 1516, 'employee_id': 'Employee_11', 'quantity_products': 48, 'order_id': 'ed8e3710-f82d-4edf-ae71-8271a56e66c5', 'commune': 'Comuna 10 - La Candelaria', 'neighborhood': 'Villa Nueva', 'partition_date': '17062024', 'event_date': '17/06/2024 17:42:59', 'event_day': 17, 'event_hour': 17, 'event_minute': 42, 'event_month': 6, 'event_second': 59, 'event_year': 2024, 'current_temperature': 24.0}
# Enviado: {'latitude': 6.263214, 'longitude': -75.565651, 'date': '17/06/2024 17:43:01', 'customer_id': 1419, 'employee_id': 'Employee_117', 'quantity_products': 49, 'order_id': '5add2bcd-514d-409a-99a3-32e8916cc3f1', 'commune': 'Comuna 10 - La Candelaria', 'neighborhood': 'Prado', 'partition_date': '17062024', 'event_date': '17/06/2024 17:43:01', 'event_day': 17, 'event_hour': 17, 'event_minute': 43, 'event_month': 6, 'event_second': 1, 'event_year': 2024, 'current_temperature': 24.0}
# Enviado: {'latitude': 6.301091, 'longitude': -75.548209, 'date': '17/06/2024 17:43:02', 'customer_id': 1730, 'employee_id': 'Employee_115', 'quantity_products': 44, 'order_id': '941426c8-e0c9-47a4-97d2-d6a247eeb670', 'commune': 'Comuna 1 - Popular', 'neighborhood': 'Popular', 'partition_date': '17062024', 'event_date': '17/06/2024 17:43:02', 'event_day': 17, 'event_hour': 17, 'event_minute': 43, 'event_month': 6, 'event_second': 2, 'event_year': 2024, 'current_temperature': 24.0}
# Enviado: {'latitude': 6.274511, 'longitude': -75.54669, 'date': '17/06/2024 17:43:03', 'customer_id': 1900, 'employee_id': 'Employee_67', 'quantity_products': 43, 'order_id': '449a0a92-9c6f-4943-a720-f731a8000237', 'commune': 'Comuna 3 - Manrique', 'neighborhood': 'Santa Inés', 'partition_date': '17062024', 'event_date': '17/06/2024 17:43:03', 'event_day': 17, 'event_hour': 17, 'event_minute': 43, 'event_month': 6, 'event_second': 3, 'event_year': 2024, 'current_temperature': 24.0}
# Enviado: {'latitude': 6.294688, 'longitude': -75.547412, 'date': '17/06/2024 17:43:04', 'customer_id': 1689, 'employee_id': 'Employee_195', 'quantity_products': 48, 'order_id': '4152d1f0-e4c3-49e4-8312-4b6f2f6f8c69', 'commune': 'Comuna 1 - Popular', 'neighborhood': 'Granizal', 'partition_date': '17062024', 'event_date': '17/06/2024 17:43:04', 'event_day': 17, 'event_hour': 17, 'event_minute': 43, 'event_month': 6, 'event_second': 4, 'event_year': 2024, 'current_temperature': 24.0}
# Enviado: {'latitude': 6.226848, 'longitude': -75.550744, 'date': '17/06/2024 17:43:05', 'customer_id': 1404, 'employee_id': 'Employee_175', 'quantity_products': 48, 'order_id': '50159d4e-f534-4ba5-b548-f50b51f5defb', 'commune': 'Comuna 9 - Buenos Aires', 'neighborhood': 'Bomboná No. 2', 'partition_date': '17062024', 'event_date': '17/06/2024 17:43:05', 'event_day': 17, 'event_hour': 17, 'event_minute': 43, 'event_month': 6, 'event_second': 5, 'event_year': 2024, 'current_temperature': 24.0}
# Enviado: {'latitude': 6.299954, 'longitude': -75.559406, 'date': '17/06/2024 17:43:06', 'customer_id': 1365, 'employee_id': 'Employee_141', 'quantity_products': 50, 'order_id': 'cb6a7e38-5935-4b8b-b556-5fe3cc5726a5', 'commune': 'Comuna 5 - Castilla', 'neighborhood': 'Héctor Abad Gómez', 'partition_date': '17062024', 'event_date': '17/06/2024 17:43:06', 'event_day': 17, 'event_hour': 17, 'event_minute': 43, 'event_month': 6, 'event_second': 6, 'event_year': 2024, 'current_temperature': 24.0}
# Enviado: {'latitude': 6.250895, 'longitude': -75.564412, 'date': '17/06/2024 17:43:07', 'customer_id': 1417, 'employee_id': 'Employee_193', 'quantity_products': 50, 'order_id': 'f19c3060-5722-45c9-a501-504e8c53198f', 'commune': 'Comuna 10 - La Candelaria', 'neighborhood': 'La Candelaria', 'partition_date': '17062024', 'event_date': '17/06/2024 17:43:07', 'event_day': 17, 'event_hour': 17, 'event_minute': 43, 'event_month': 6, 'event_second': 7, 'event_year': 2024, 'current_temperature': 24.0}
# Enviado: {'latitude': 6.300545, 'longitude': -75.563593, 'date': '17/06/2024 17:43:08', 'customer_id': 1573, 'employee_id': 'Employee_179', 'quantity_products': 50, 'order_id': '88791680-178f-4206-9bf1-faea6facb15d', 'commune': 'Comuna 5 - Castilla', 'neighborhood': 'Boyacá', 'partition_date': '17062024', 'event_date': '17/06/2024 17:43:08', 'event_day': 17, 'event_hour': 17, 'event_minute': 43, 'event_month': 6, 'event_second': 8, 'event_year': 2024, 'current_temperature': 24.0}
# Enviado: {'latitude': 6.233505, 'longitude': -75.539321, 'date': '17/06/2024 17:43:09', 'customer_id': 1747, 'employee_id': 'Employee_103', 'quantity_products': 50, 'order_id': 'c2995bf1-43b8-4975-865c-8ac94880f85a', 'commune': 'Comuna 8 - Villa Hermosa', 'neighborhood': 'Villa Tina', 'partition_date': '17062024', 'event_date': '17/06/2024 17:43:09', 'event_day': 17, 'event_hour': 17, 'event_minute': 43, 'event_month': 6, 'event_second': 9, 'event_year': 2024, 'current_temperature': 24.0}
# Enviado: {'latitude': 6.304733, 'longitude': -75.563183, 'date': '17/06/2024 17:43:10', 'customer_id': 1387, 'employee_id': 'Employee_55', 'quantity_products': 41, 'order_id': '5a178f24-46f9-4eee-b694-907d18951947', 'commune': 'Comuna 5 - Castilla', 'neighborhood': 'Boyacá', 'partition_date': '17062024', 'event_date': '17/06/2024 17:43:10', 'event_day': 17, 'event_hour': 17, 'event_minute': 43, 'event_month': 6, 'event_second': 10, 'event_year': 2024, 'current_temperature': 24.0}
# Enviado: {'latitude': 6.296513, 'longitude': -75.565534, 'date': '17/06/2024 17:43:11', 'customer_id': 1223, 'employee_id': 'Employee_43', 'quantity_products': 50, 'order_id': '5a699697-aa68-4ba2-b446-81ff5d8c63f3', 'commune': 'Comuna 5 - Castilla', 'neighborhood': 'Belalcázar', 'partition_date': '17062024', 'event_date': '17/06/2024 17:43:11', 'event_day': 17, 'event_hour': 17, 'event_minute': 43, 'event_month': 6, 'event_second': 11, 'event_year': 2024, 'current_temperature': 24.0}
# Enviado: {'latitude': 6.221932, 'longitude': -75.528966, 'date': '17/06/2024 17:43:12', 'customer_id': 1813, 'employee_id': 'Employee_41', 'quantity_products': 35, 'order_id': '23df7c0c-f193-42d9-90d9-c5725108683f', 'commune': 'Comuna 9 - Buenos Aires', 'neighborhood': 'Ocho de Marzo', 'partition_date': '17062024', 'event_date': '17/06/2024 17:43:12', 'event_day': 17, 'event_hour': 17, 'event_minute': 43, 'event_month': 6, 'event_second': 12, 'event_year': 2024, 'current_temperature': 24.0}
# Enviado: {'latitude': 6.271556, 'longitude': -75.54339, 'date': '17/06/2024 17:43:13', 'customer_id': 1613, 'employee_id': 'Employee_155', 'quantity_products': 45, 'order_id': '0b5190f6-7625-440a-9333-aeed2ae7d3bc', 'commune': 'Comuna 3 - Manrique', 'neighborhood': 'La Cruz', 'partition_date': '17062024', 'event_date': '17/06/2024 17:43:13', 'event_day': 17, 'event_hour': 17, 'event_minute': 43, 'event_month': 6, 'event_second': 13, 'event_year': 2024, 'current_temperature': 24.0}
# Enviado: {'latitude': 6.30199, 'longitude': -75.565785, 'date': '17/06/2024 17:43:14', 'customer_id': 1192, 'employee_id': 'Employee_39', 'quantity_products': 27, 'order_id': 'c39e411c-e6a7-4256-a6af-3cb8eb16eb6c', 'commune': 'Comuna 5 - Castilla', 'neighborhood': 'Boyacá', 'partition_date': '17062024', 'event_date': '17/06/2024 17:43:14', 'event_day': 17, 'event_hour': 17, 'event_minute': 43, 'event_month': 6, 'event_second': 14, 'event_year': 2024, 'current_temperature': 24.0}
# Enviado: {'latitude': 6.233647, 'longitude': -75.560311, 'date': '17/06/2024 17:43:15', 'customer_id': 1692, 'employee_id': 'Employee_85', 'quantity_products': 50, 'order_id': '8200bef7-d974-46ab-adca-9a39e50777b3', 'commune': 'Comuna 9 - Buenos Aires', 'neighborhood': 'Loreto', 'partition_date': '17062024', 'event_date': '17/06/2024 17:43:15', 'event_day': 17, 'event_hour': 17, 'event_minute': 43, 'event_month': 6, 'event_second': 15, 'event_year': 2024, 'current_temperature': 24.0}
# Enviado: {'latitude': 6.226848, 'longitude': -75.550744, 'date': '17/06/2024 17:43:16', 'customer_id': 1368, 'employee_id': 'Employee_175', 'quantity_products': 50, 'order_id': '074a7666-b263-4998-9c2b-c37d2da82f0e', 'commune': 'Comuna 9 - Buenos Aires', 'neighborhood': 'Bomboná No. 2', 'partition_date': '17062024', 'event_date': '17/06/2024 17:43:16', 'event_day': 17, 'event_hour': 17, 'event_minute': 43, 'event_month': 6, 'event_second': 16, 'event_year': 2024, 'current_temperature': 24.0}
# Enviado: {'latitude': 6.288678, 'longitude': -75.556225, 'date': '17/06/2024 17:43:17', 'customer_id': 1319, 'employee_id': 'Employee_135', 'quantity_products': 47, 'order_id': '929fe8c9-fdcf-4df2-be28-82193f8561ab', 'commune': 'Comuna 4 - Aranjuez', 'neighborhood': 'Berlin', 'partition_date': '17062024', 'event_date': '17/06/2024 17:43:17', 'event_day': 17, 'event_hour': 17, 'event_minute': 43, 'event_month': 6, 'event_second': 17, 'event_year': 2024, 'current_temperature': 24.0}
# Enviado: {'latitude': 6.230978, 'longitude': -75.533582, 'date': '17/06/2024 17:43:18', 'customer_id': 1961, 'employee_id': 'Employee_9', 'quantity_products': 50, 'order_id': '946061a7-af8c-4ac5-8bff-8b49809d957c', 'commune': 'Comuna 9 - Buenos Aires', 'neighborhood': 'Barrios de Jesús', 'partition_date': '17062024', 'event_date': '17/06/2024 17:43:18', 'event_day': 17, 'event_hour': 17, 'event_minute': 43, 'event_month': 6, 'event_second': 18, 'event_year': 2024, 'current_temperature': 24.0}
# Enviado: {'latitude': 6.252831, 'longitude': -75.565694, 'date': '17/06/2024 17:43:19', 'customer_id': 1663, 'employee_id': 'Employee_11', 'quantity_products': 42, 'order_id': '8c18ed95-5ea9-4764-a6e5-02bc9a1f60ad', 'commune': 'Comuna 10 - La Candelaria', 'neighborhood': 'Villa Nueva', 'partition_date': '17062024', 'event_date': '17/06/2024 17:43:19', 'event_day': 17, 'event_hour': 17, 'event_minute': 43, 'event_month': 6, 'event_second': 19, 'event_year': 2024, 'current_temperature': 24.0}
# Enviado: {'latitude': 6.237547, 'longitude': -75.536549, 'date': '17/06/2024 17:43:20', 'customer_id': 1850, 'employee_id': 'Employee_23', 'quantity_products': 44, 'order_id': '029aa261-7898-47f3-9a16-7ef5a1e89081', 'commune': 'Comuna 8 - Villa Hermosa', 'neighborhood': 'San Antonio', 'partition_date': '17062024', 'event_date': '17/06/2024 17:43:20', 'event_day': 17, 'event_hour': 17, 'event_minute': 43, 'event_month': 6, 'event_second': 20, 'event_year': 2024, 'current_temperature': 24.0}
# Enviado: {'latitude': 6.229935, 'longitude': -75.556966, 'date': '17/06/2024 17:43:21', 'customer_id': 1287, 'employee_id': 'Employee_165', 'quantity_products': 46, 'order_id': 'fdf64792-f2cb-47a4-85bf-e9fcc72ca665', 'commune': 'Comuna 9 - Buenos Aires', 'neighborhood': 'Loreto', 'partition_date': '17062024', 'event_date': '17/06/2024 17:43:21', 'event_day': 17, 'event_hour': 17, 'event_minute': 43, 'event_month': 6, 'event_second': 21, 'event_year': 2024, 'current_temperature': 24.0}
# Enviado: {'latitude': 6.23482, 'longitude': -75.54546, 'date': '17/06/2024 17:43:22', 'customer_id': 1760, 'employee_id': 'Employee_149', 'quantity_products': 50, 'order_id': 'a548a392-a806-4882-8134-49b7de257d9d', 'commune': 'Comuna 9 - Buenos Aires', 'neighborhood': 'Los Cerros - El Vergel', 'partition_date': '17062024', 'event_date': '17/06/2024 17:43:22', 'event_day': 17, 'event_hour': 17, 'event_minute': 43, 'event_month': 6, 'event_second': 22, 'event_year': 2024, 'current_temperature': 24.0}
# Enviado: {'latitude': 6.295899, 'longitude': -75.539886, 'date': '17/06/2024 17:43:23', 'customer_id': 1212, 'employee_id': 'Employee_59', 'quantity_products': 40, 'order_id': '3ff8b1d7-ea0c-45be-a560-1c04607c4656', 'commune': 'Comuna 1 - Popular', 'neighborhood': 'La Avanzada', 'partition_date': '17062024', 'event_date': '17/06/2024 17:43:23', 'event_day': 17, 'event_hour': 17, 'event_minute': 43, 'event_month': 6, 'event_second': 23, 'event_year': 2024, 'current_temperature': 24.0}
# Enviado: {'latitude': 6.274861, 'longitude': -75.533979, 'date': '17/06/2024 17:43:24', 'customer_id': 1623, 'employee_id': 'Employee_161', 'quantity_products': 50, 'order_id': 'ce1e5e75-52c6-475a-be21-236e70d01abf', 'commune': 'Comuna 3 - Manrique', 'neighborhood': 'La Cruz', 'partition_date': '17062024', 'event_date': '17/06/2024 17:43:24', 'event_day': 17, 'event_hour': 17, 'event_minute': 43, 'event_month': 6, 'event_second': 24, 'event_year': 2024, 'current_temperature': 24.0}
# Enviado: {'latitude': 6.302827, 'longitude': -75.560455, 'date': '17/06/2024 17:43:25', 'customer_id': 1083, 'employee_id': 'Employee_63', 'quantity_products': 50, 'order_id': '82693763-23e4-4e5b-8676-78d1169d6f45', 'commune': 'Comuna 5 - Castilla', 'neighborhood': 'Héctor Abad Gómez', 'partition_date': '17062024', 'event_date': '17/06/2024 17:43:25', 'event_day': 17, 'event_hour': 17, 'event_minute': 43, 'event_month': 6, 'event_second': 25, 'event_year': 2024, 'current_temperature': 24.0}
# Enviado: {'latitude': 6.300545, 'longitude': -75.563593, 'date': '17/06/2024 17:43:26', 'customer_id': 1831, 'employee_id': 'Employee_179', 'quantity_products': 50, 'order_id': '5fba450d-6ce1-4e38-b736-ec3e8dd260f5', 'commune': 'Comuna 5 - Castilla', 'neighborhood': 'Boyacá', 'partition_date': '17062024', 'event_date': '17/06/2024 17:43:26', 'event_day': 17, 'event_hour': 17, 'event_minute': 43, 'event_month': 6, 'event_second': 26, 'event_year': 2024, 'current_temperature': 24.0}
# Enviado: {'latitude': 6.23618, 'longitude': -75.557692, 'date': '17/06/2024 17:43:27', 'customer_id': 1171, 'employee_id': 'Employee_169', 'quantity_products': 47, 'order_id': '897f839b-4825-4d13-b5ac-2b72c7b5b1f4', 'commune': 'Comuna 9 - Buenos Aires', 'neighborhood': 'Gerona', 'partition_date': '17062024', 'event_date': '17/06/2024 17:43:27', 'event_day': 17, 'event_hour': 17, 'event_minute': 43, 'event_month': 6, 'event_second': 27, 'event_year': 2024, 'current_temperature': 24.0}
# Enviado: {'latitude': 6.240886, 'longitude': -75.5567, 'date': '17/06/2024 17:43:28', 'customer_id': 1392, 'employee_id': 'Employee_125', 'quantity_products': 50, 'order_id': '7b37bbae-8748-4b0f-97a2-5a7a74a11919', 'commune': 'Comuna 9 - Buenos Aires', 'neighborhood': 'Buenos Aires', 'partition_date': '17062024', 'event_date': '17/06/2024 17:43:28', 'event_day': 17, 'event_hour': 17, 'event_minute': 43, 'event_month': 6, 'event_second': 28, 'event_year': 2024, 'current_temperature': 24.0}
# Enviado: {'latitude': 6.302827, 'longitude': -75.560455, 'date': '17/06/2024 17:43:29', 'customer_id': 1181, 'employee_id': 'Employee_63', 'quantity_products': 50, 'order_id': 'ccc54e3c-ae44-4f5d-99da-a63197e5b22b', 'commune': 'Comuna 5 - Castilla', 'neighborhood': 'Héctor Abad Gómez', 'partition_date': '17062024', 'event_date': '17/06/2024 17:43:29', 'event_day': 17, 'event_hour': 17, 'event_minute': 43, 'event_month': 6, 'event_second': 29, 'event_year': 2024, 'current_temperature': 24.0}
# Enviado: {'latitude': 6.231588, 'longitude': -75.541907, 'date': '17/06/2024 17:43:30', 'customer_id': 1356, 'employee_id': 'Employee_105', 'quantity_products': 33, 'order_id': '9c5d31d5-0c3a-4191-99b6-b076e6a3280d', 'commune': 'Comuna 9 - Buenos Aires', 'neighborhood': 'Bomboná No. 2', 'partition_date': '17062024', 'event_date': '17/06/2024 17:43:30', 'event_day': 17, 'event_hour': 17, 'event_minute': 43, 'event_month': 6, 'event_second': 30, 'event_year': 2024, 'current_temperature': 24.0}
# Enviado: {'latitude': 6.240547, 'longitude': -75.537934, 'date': '17/06/2024 17:43:31', 'customer_id': 1377, 'employee_id': 'Employee_75', 'quantity_products': 50, 'order_id': 'b6fb42a2-a0b5-41c7-a150-76a81c7195fe', 'commune': 'Comuna 8 - Villa Hermosa', 'neighborhood': 'Villa Tina', 'partition_date': '17062024', 'event_date': '17/06/2024 17:43:31', 'event_day': 17, 'event_hour': 17, 'event_minute': 43, 'event_month': 6, 'event_second': 31, 'event_year': 2024, 'current_temperature': 24.0}
# Enviado: {'latitude': 6.296513, 'longitude': -75.565534, 'date': '17/06/2024 17:43:32', 'customer_id': 1475, 'employee_id': 'Employee_43', 'quantity_products': 40, 'order_id': 'b3835113-939d-4607-9814-7932db815796', 'commune': 'Comuna 5 - Castilla', 'neighborhood': 'Belalcázar', 'partition_date': '17062024', 'event_date': '17/06/2024 17:43:32', 'event_day': 17, 'event_hour': 17, 'event_minute': 43, 'event_month': 6, 'event_second': 32, 'event_year': 2024, 'current_temperature': 24.0}
# Enviado: {'latitude': 6.232589, 'longitude': -75.56674, 'date': '17/06/2024 17:43:33', 'customer_id': 1421, 'employee_id': 'Employee_111', 'quantity_products': 50, 'order_id': 'a42f2499-77e8-484d-8b05-541cee728f56', 'commune': 'Comuna 10 - La Candelaria', 'neighborhood': 'Barrio San Diego', 'partition_date': '17062024', 'event_date': '17/06/2024 17:43:33', 'event_day': 17, 'event_hour': 17, 'event_minute': 43, 'event_month': 6, 'event_second': 33, 'event_year': 2024, 'current_temperature': 24.0}
# Enviado: {'latitude': 6.297461, 'longitude': -75.557846, 'date': '17/06/2024 17:43:34', 'customer_id': 1227, 'employee_id': 'Employee_3', 'quantity_products': 38, 'order_id': '0490bb57-29f0-4ae8-bc1f-26229c836858', 'commune': 'Comuna 2 - Santa Cruz', 'neighborhood': 'Santa Cruz', 'partition_date': '17062024', 'event_date': '17/06/2024 17:43:34', 'event_day': 17, 'event_hour': 17, 'event_minute': 43, 'event_month': 6, 'event_second': 34, 'event_year': 2024, 'current_temperature': 24.0}
# Enviado: {'latitude': 6.252563, 'longitude': -75.538641, 'date': '17/06/2024 17:43:35', 'customer_id': 1975, 'employee_id': 'Employee_89', 'quantity_products': 50, 'order_id': '46b287a6-d49c-4a02-9e07-9a6714e3ced5', 'commune': 'Comuna 8 - Villa Hermosa', 'neighborhood': 'Llanaditas', 'partition_date': '17062024', 'event_date': '17/06/2024 17:43:35', 'event_day': 17, 'event_hour': 17, 'event_minute': 43, 'event_month': 6, 'event_second': 35, 'event_year': 2024, 'current_temperature': 24.0}
# Enviado: {'latitude': 6.302827, 'longitude': -75.560455, 'date': '17/06/2024 17:43:36', 'customer_id': 1465, 'employee_id': 'Employee_63', 'quantity_products': 50, 'order_id': 'a360f1df-0efb-4c12-a8a8-f36364fdb3a9', 'commune': 'Comuna 5 - Castilla', 'neighborhood': 'Héctor Abad Gómez', 'partition_date': '17062024', 'event_date': '17/06/2024 17:43:36', 'event_day': 17, 'event_hour': 17, 'event_minute': 43, 'event_month': 6, 'event_second': 36, 'event_year': 2024, 'current_temperature': 24.0}
# Enviado: {'latitude': 6.236558, 'longitude': -75.558081, 'date': '17/06/2024 17:43:37', 'customer_id': 1187, 'employee_id': 'Employee_35', 'quantity_products': 41, 'order_id': '365384df-3684-497f-868c-753e6a858950', 'commune': 'Comuna 9 - Buenos Aires', 'neighborhood': 'Gerona', 'partition_date': '17062024', 'event_date': '17/06/2024 17:43:37', 'event_day': 17, 'event_hour': 17, 'event_minute': 43, 'event_month': 6, 'event_second': 37, 'event_year': 2024, 'current_temperature': 24.0}
# Enviado: {'latitude': 6.226864, 'longitude': -75.52891, 'date': '17/06/2024 17:43:38', 'customer_id': 1630, 'employee_id': 'Employee_65', 'quantity_products': 44, 'order_id': '446eeafa-07ff-473e-b1b3-504c75a3cd2b', 'commune': 'Comuna 9 - Buenos Aires', 'neighborhood': 'Ocho de Marzo', 'partition_date': '17062024', 'event_date': '17/06/2024 17:43:38', 'event_day': 17, 'event_hour': 17, 'event_minute': 43, 'event_month': 6, 'event_second': 38, 'event_year': 2024, 'current_temperature': 24.0}
# Enviado: {'latitude': 6.251305, 'longitude': -75.539935, 'date': '17/06/2024 17:43:39', 'customer_id': 1339, 'employee_id': 'Employee_95', 'quantity_products': 48, 'order_id': '0880c089-44b6-46c7-be74-e98221062a7b', 'commune': 'Comuna 8 - Villa Hermosa', 'neighborhood': 'Llanaditas', 'partition_date': '17062024', 'event_date': '17/06/2024 17:43:39', 'event_day': 17, 'event_hour': 17, 'event_minute': 43, 'event_month': 6, 'event_second': 39, 'event_year': 2024, 'current_temperature': 24.0}
# Enviado: {'latitude': 6.30199, 'longitude': -75.565785, 'date': '17/06/2024 17:43:40', 'customer_id': 1697, 'employee_id': 'Employee_39', 'quantity_products': 50, 'order_id': '4d4db08a-01f8-4f3d-b8f9-bdf8688fb360', 'commune': 'Comuna 5 - Castilla', 'neighborhood': 'Boyacá', 'partition_date': '17062024', 'event_date': '17/06/2024 17:43:40', 'event_day': 17, 'event_hour': 17, 'event_minute': 43, 'event_month': 6, 'event_second': 40, 'event_year': 2024, 'current_temperature': 24.0}
# Enviado: {'latitude': 6.299064, 'longitude': -75.545337, 'date': '17/06/2024 17:43:41', 'customer_id': 1497, 'employee_id': 'Employee_13', 'quantity_products': 30, 'order_id': 'a9abeda9-18e3-4c01-a34b-2b4f3462a1d2', 'commune': 'Comuna 1 - Popular', 'neighborhood': 'Santo Domingo Savio No.1', 'partition_date': '17062024', 'event_date': '17/06/2024 17:43:41', 'event_day': 17, 'event_hour': 17, 'event_minute': 43, 'event_month': 6, 'event_second': 41, 'event_year': 2024, 'current_temperature': 24.0}
# Enviado: {'latitude': 6.256553, 'longitude': -75.552019, 'date': '17/06/2024 17:43:42', 'customer_id': 1926, 'employee_id': 'Employee_7', 'quantity_products': 38, 'order_id': '2129ed42-d3ad-4cb5-aebf-85ee19b67687', 'commune': 'Comuna 8 - Villa Hermosa', 'neighborhood': 'Villa Hermosa', 'partition_date': '17062024', 'event_date': '17/06/2024 17:43:42', 'event_day': 17, 'event_hour': 17, 'event_minute': 43, 'event_month': 6, 'event_second': 42, 'event_year': 2024, 'current_temperature': 24.0}
# Enviado: {'latitude': 6.230866, 'longitude': -75.530405, 'date': '17/06/2024 17:43:43', 'customer_id': 1833, 'employee_id': 'Employee_81', 'quantity_products': 37, 'order_id': '026890d4-2eb5-4a5a-80d5-0bce73bbee11', 'commune': 'Comuna 8 - Villa Hermosa', 'neighborhood': 'Las Estancias', 'partition_date': '17062024', 'event_date': '17/06/2024 17:43:43', 'event_day': 17, 'event_hour': 17, 'event_minute': 43, 'event_month': 6, 'event_second': 43, 'event_year': 2024, 'current_temperature': 24.0}
# Enviado: {'latitude': 6.299064, 'longitude': -75.545337, 'date': '17/06/2024 17:43:44', 'customer_id': 1065, 'employee_id': 'Employee_13', 'quantity_products': 31, 'order_id': 'dd6b84c4-f5be-47e8-8c3b-c68bf7b998b0', 'commune': 'Comuna 1 - Popular', 'neighborhood': 'Santo Domingo Savio No.1', 'partition_date': '17062024', 'event_date': '17/06/2024 17:43:44', 'event_day': 17, 'event_hour': 17, 'event_minute': 43, 'event_month': 6, 'event_second': 44, 'event_year': 2024, 'current_temperature': 24.0}
# Enviado: {'latitude': 6.267149, 'longitude': -75.539398, 'date': '17/06/2024 17:43:45', 'customer_id': 1412, 'employee_id': 'Employee_97', 'quantity_products': 50, 'order_id': '0c68f987-6262-4e4a-ab66-108f196ac1d7', 'commune': 'Comuna 3 - Manrique', 'neighborhood': 'Versalles No. 2', 'partition_date': '17062024', 'event_date': '17/06/2024 17:43:45', 'event_day': 17, 'event_hour': 17, 'event_minute': 43, 'event_month': 6, 'event_second': 45, 'event_year': 2024, 'current_temperature': 24.0}
# Enviado: {'latitude': 6.254946, 'longitude': -75.558221, 'date': '17/06/2024 17:43:46', 'customer_id': 1531, 'employee_id': 'Employee_147', 'quantity_products': 50, 'order_id': '2cf2d702-c726-4baf-b12e-b8630c9728f1', 'commune': 'Comuna 8 - Villa Hermosa', 'neighborhood': 'San Miguel', 'partition_date': '17062024', 'event_date': '17/06/2024 17:43:46', 'event_day': 17, 'event_hour': 17, 'event_minute': 43, 'event_month': 6, 'event_second': 46, 'event_year': 2024, 'current_temperature': 24.0}
# Enviado: {'latitude': 6.23618, 'longitude': -75.557692, 'date': '17/06/2024 17:43:47', 'customer_id': 1948, 'employee_id': 'Employee_169', 'quantity_products': 38, 'order_id': '601df4e1-20f6-4819-b109-5bbf29f794a0', 'commune': 'Comuna 9 - Buenos Aires', 'neighborhood': 'Gerona', 'partition_date': '17062024', 'event_date': '17/06/2024 17:43:47', 'event_day': 17, 'event_hour': 17, 'event_minute': 43, 'event_month': 6, 'event_second': 47, 'event_year': 2024, 'current_temperature': 24.0}
# Enviado: {'latitude': 6.221932, 'longitude': -75.528966, 'date': '17/06/2024 17:43:48', 'customer_id': 1480, 'employee_id': 'Employee_41', 'quantity_products': 50, 'order_id': 'cfbba2b4-2f1d-4c38-be24-34a4fdee1666', 'commune': 'Comuna 9 - Buenos Aires', 'neighborhood': 'Ocho de Marzo', 'partition_date': '17062024', 'event_date': '17/06/2024 17:43:48', 'event_day': 17, 'event_hour': 17, 'event_minute': 43, 'event_month': 6, 'event_second': 48, 'event_year': 2024, 'current_temperature': 24.0}
# ...
# Enviado: {'latitude': 6.263089, 'longitude': -75.562475, 'date': '17/06/2024 17:47:13', 'customer_id': 1581, 'employee_id': 'Employee_69', 'quantity_products': 43, 'order_id': '24819797-a8b8-4ab6-bce2-53764a1ca692', 'commune': 'Comuna 10 - La Candelaria', 'neighborhood': 'Prado', 'partition_date': '17062024', 'event_date': '17/06/2024 17:47:13', 'event_day': 17, 'event_hour': 17, 'event_minute': 47, 'event_month': 6, 'event_second': 13, 'event_year': 2024, 'current_temperature': 24.0}
# Enviado: {'latitude': 6.236558, 'longitude': -75.558081, 'date': '17/06/2024 17:47:14', 'customer_id': 1192, 'employee_id': 'Employee_35', 'quantity_products': 46, 'order_id': 'c39fbeca-58b3-4a06-8113-e36f9c454d49', 'commune': 'Comuna 9 - Buenos Aires', 'neighborhood': 'Gerona', 'partition_date': '17062024', 'event_date': '17/06/2024 17:47:14', 'event_day': 17, 'event_hour': 17, 'event_minute': 47, 'event_month': 6, 'event_second': 14, 'event_year': 2024, 'current_temperature': 24.0}
# Enviado: {'latitude': 6.230866, 'longitude': -75.530405, 'date': '17/06/2024 17:47:15', 'customer_id': 1829, 'employee_id': 'Employee_81', 'quantity_products': 50, 'order_id': '5e3ac7d0-4112-4b85-ad8a-a9294c73990c', 'commune': 'Comuna 8 - Villa Hermosa', 'neighborhood': 'Las Estancias', 'partition_date': '17062024', 'event_date': '17/06/2024 17:47:15', 'event_day': 17, 'event_hour': 17, 'event_minute': 47, 'event_month': 6, 'event_second': 15, 'event_year': 2024, 'current_temperature': 24.0}
# Enviado: {'latitude': 6.232999, 'longitude': -75.53153, 'date': '17/06/2024 17:47:16', 'customer_id': 1134, 'employee_id': 'Employee_99', 'quantity_products': 50, 'order_id': '86c23e8a-c7c5-45f9-8d08-0aefe1b96b7d', 'commune': 'Comuna 8 - Villa Hermosa', 'neighborhood': 'Las Estancias', 'partition_date': '17062024', 'event_date': '17/06/2024 17:47:16', 'event_day': 17, 'event_hour': 17, 'event_minute': 47, 'event_month': 6, 'event_second': 16, 'event_year': 2024, 'current_temperature': 24.0}
# Enviado: {'latitude': 6.299064, 'longitude': -75.545337, 'date': '17/06/2024 17:47:17', 'customer_id': 1814, 'employee_id': 'Employee_13', 'quantity_products': 50, 'order_id': '29ea9a44-df55-4394-894a-c0f9e87f2a02', 'commune': 'Comuna 1 - Popular', 'neighborhood': 'Santo Domingo Savio No.1', 'partition_date': '17062024', 'event_date': '17/06/2024 17:47:17', 'event_day': 17, 'event_hour': 17, 'event_minute': 47, 'event_month': 6, 'event_second': 17, 'event_year': 2024, 'current_temperature': 24.0}
# Enviado: {'latitude': 6.241009, 'longitude': -75.533801, 'date': '17/06/2024 17:47:18', 'customer_id': 1837, 'employee_id': 'Employee_131', 'quantity_products': 48, 'order_id': '87328e72-260c-4e79-a84a-10001b96852b', 'commune': 'Comuna 8 - Villa Hermosa', 'neighborhood': 'Esfuerzos de Paz', 'partition_date': '17062024', 'event_date': '17/06/2024 17:47:18', 'event_day': 17, 'event_hour': 17, 'event_minute': 47, 'event_month': 6, 'event_second': 18, 'event_year': 2024, 'current_temperature': 24.0}
# Enviado: {'latitude': 6.243445, 'longitude': -75.548496, 'date': '17/06/2024 17:47:19', 'customer_id': 1467, 'employee_id': 'Employee_25', 'quantity_products': 50, 'order_id': 'eb76add0-159c-45c1-af07-460b655ac728', 'commune': 'Comuna 8 - Villa Hermosa', 'neighborhood': 'El Pinal', 'partition_date': '17062024', 'event_date': '17/06/2024 17:47:19', 'event_day': 17, 'event_hour': 17, 'event_minute': 47, 'event_month': 6, 'event_second': 19, 'event_year': 2024, 'current_temperature': 24.0}
# Enviado: {'latitude': 6.255342, 'longitude': -75.555875, 'date': '17/06/2024 17:47:20', 'customer_id': 1504, 'employee_id': 'Employee_157', 'quantity_products': 50, 'order_id': '2d0280a8-5c2a-4830-bb51-cba675f8b66f', 'commune': 'Comuna 8 - Villa Hermosa', 'neighborhood': 'San Miguel', 'partition_date': '17062024', 'event_date': '17/06/2024 17:47:20', 'event_day': 17, 'event_hour': 17, 'event_minute': 47, 'event_month': 6, 'event_second': 20, 'event_year': 2024, 'current_temperature': 24.0}
# Enviado: {'latitude': 6.271556, 'longitude': -75.54339, 'date': '17/06/2024 17:47:21', 'customer_id': 1806, 'employee_id': 'Employee_155', 'quantity_products': 50, 'order_id': '2e55694d-215e-4e33-8689-11cc7f515a11', 'commune': 'Comuna 3 - Manrique', 'neighborhood': 'La Cruz', 'partition_date': '17062024', 'event_date': '17/06/2024 17:47:21', 'event_day': 17, 'event_hour': 17, 'event_minute': 47, 'event_month': 6, 'event_second': 21, 'event_year': 2024, 'current_temperature': 24.0}
# Enviado: {'latitude': 6.272454, 'longitude': -75.55848, 'date': '17/06/2024 17:47:22', 'customer_id': 1788, 'employee_id': 'Employee_87', 'quantity_products': 50, 'order_id': '43561bbb-4c47-4cd1-ae09-022255417de3', 'commune': 'Comuna 4 - Aranjuez', 'neighborhood': 'Brasilia', 'partition_date': '17062024', 'event_date': '17/06/2024 17:47:22', 'event_day': 17, 'event_hour': 17, 'event_minute': 47, 'event_month': 6, 'event_second': 22, 'event_year': 2024, 'current_temperature': 24.0}
# Enviado: {'latitude': 6.272034, 'longitude': -75.549212, 'date': '17/06/2024 17:47:23', 'customer_id': 1124, 'employee_id': 'Employee_53', 'quantity_products': 37, 'order_id': '07915ece-661a-4de6-bd82-9629b4d83d2b', 'commune': 'Comuna 3 - Manrique', 'neighborhood': 'Santa Inés', 'partition_date': '17062024', 'event_date': '17/06/2024 17:47:23', 'event_day': 17, 'event_hour': 17, 'event_minute': 47, 'event_month': 6, 'event_second': 23, 'event_year': 2024, 'current_temperature': 24.0}
# Enviado: {'latitude': 6.232589, 'longitude': -75.56674, 'date': '17/06/2024 17:47:24', 'customer_id': 1108, 'employee_id': 'Employee_111', 'quantity_products': 50, 'order_id': 'b89666c3-3a54-41af-a602-696f7ed8e798', 'commune': 'Comuna 10 - La Candelaria', 'neighborhood': 'Barrio San Diego', 'partition_date': '17062024', 'event_date': '17/06/2024 17:47:24', 'event_day': 17, 'event_hour': 17, 'event_minute': 47, 'event_month': 6, 'event_second': 24, 'event_year': 2024, 'current_temperature': 24.0}
# Enviado: {'latitude': 6.233249, 'longitude': -75.544511, 'date': '17/06/2024 17:47:25', 'customer_id': 1242, 'employee_id': 'Employee_153', 'quantity_products': 49, 'order_id': 'de49df81-b6c6-451e-9f75-3eeb0b98b644', 'commune': 'Comuna 9 - Buenos Aires', 'neighborhood': 'Los Cerros - El Vergel', 'partition_date': '17062024', 'event_date': '17/06/2024 17:47:25', 'event_day': 17, 'event_hour': 17, 'event_minute': 47, 'event_month': 6, 'event_second': 25, 'event_year': 2024, 'current_temperature': 24.0}
# Enviado: {'latitude': 6.298824, 'longitude': -75.547453, 'date': '17/06/2024 17:47:26', 'customer_id': 1586, 'employee_id': 'Employee_1', 'quantity_products': 50, 'order_id': '62f4708f-3f9e-4af3-934a-360cbc9b23cc', 'commune': 'Comuna 1 - Popular', 'neighborhood': 'Popular', 'partition_date': '17062024', 'event_date': '17/06/2024 17:47:26', 'event_day': 17, 'event_hour': 17, 'event_minute': 47, 'event_month': 6, 'event_second': 26, 'event_year': 2024, 'current_temperature': 24.0}
# Enviado: {'latitude': 6.252726, 'longitude': -75.558396, 'date': '17/06/2024 17:47:27', 'customer_id': 1704, 'employee_id': 'Employee_61', 'quantity_products': 41, 'order_id': '7a817596-3061-45b6-b206-9c3fec40a6b4', 'commune': 'Comuna 10 - La Candelaria', 'neighborhood': 'Los Ángeles', 'partition_date': '17062024', 'event_date': '17/06/2024 17:47:27', 'event_day': 17, 'event_hour': 17, 'event_minute': 47, 'event_month': 6, 'event_second': 27, 'event_year': 2024, 'current_temperature': 24.0}
# Enviado: {'latitude': 6.272453, 'longitude': -75.542127, 'date': '17/06/2024 17:47:28', 'customer_id': 1109, 'employee_id': 'Employee_139', 'quantity_products': 50, 'order_id': '29397476-0bf0-4e3e-b8e9-aaebe3b6d476', 'commune': 'Comuna 3 - Manrique', 'neighborhood': 'Oriente', 'partition_date': '17062024', 'event_date': '17/06/2024 17:47:28', 'event_day': 17, 'event_hour': 17, 'event_minute': 47, 'event_month': 6, 'event_second': 28, 'event_year': 2024, 'current_temperature': 24.0}
# Enviado: {'latitude': 6.228153, 'longitude': -75.52915, 'date': '17/06/2024 17:47:29', 'customer_id': 1295, 'employee_id': 'Employee_185', 'quantity_products': 41, 'order_id': '0d1e5275-8f9c-43a2-b29a-214098901a43', 'commune': 'Comuna 9 - Buenos Aires', 'neighborhood': 'Ocho de Marzo', 'partition_date': '17062024', 'event_date': '17/06/2024 17:47:29', 'event_day': 17, 'event_hour': 17, 'event_minute': 47, 'event_month': 6, 'event_second': 29, 'event_year': 2024, 'current_temperature': 24.0}
# Enviado: {'latitude': 6.231588, 'longitude': -75.541907, 'date': '17/06/2024 17:47:30', 'customer_id': 1333, 'employee_id': 'Employee_105', 'quantity_products': 50, 'order_id': '7496e7fe-e588-4ae6-a73e-1f1aa32388d6', 'commune': 'Comuna 9 - Buenos Aires', 'neighborhood': 'Bomboná No. 2', 'partition_date': '17062024', 'event_date': '17/06/2024 17:47:30', 'event_day': 17, 'event_hour': 17, 'event_minute': 47, 'event_month': 6, 'event_second': 30, 'event_year': 2024, 'current_temperature': 24.0}
# Enviado: {'latitude': 6.236558, 'longitude': -75.558081, 'date': '17/06/2024 17:47:31', 'customer_id': 1179, 'employee_id': 'Employee_35', 'quantity_products': 49, 'order_id': '2e1f416d-2f2e-4bed-a0c5-e579a0ef69a1', 'commune': 'Comuna 9 - Buenos Aires', 'neighborhood': 'Gerona', 'partition_date': '17062024', 'event_date': '17/06/2024 17:47:31', 'event_day': 17, 'event_hour': 17, 'event_minute': 47, 'event_month': 6, 'event_second': 31, 'event_year': 2024, 'current_temperature': 24.0}
# Enviado: {'latitude': 6.228153, 'longitude': -75.52915, 'date': '17/06/2024 17:47:32', 'customer_id': 1788, 'employee_id': 'Employee_185', 'quantity_products': 50, 'order_id': '6afe3ac6-08fd-4872-8f59-7717ae481fb8', 'commune': 'Comuna 9 - Buenos Aires', 'neighborhood': 'Ocho de Marzo', 'partition_date': '17062024', 'event_date': '17/06/2024 17:47:32', 'event_day': 17, 'event_hour': 17, 'event_minute': 47, 'event_month': 6, 'event_second': 32, 'event_year': 2024, 'current_temperature': 24.0}
# Enviado: {'latitude': 6.272454, 'longitude': -75.55848, 'date': '17/06/2024 17:47:33', 'customer_id': 1325, 'employee_id': 'Employee_87', 'quantity_products': 50, 'order_id': '823a4555-b8df-44a7-b57b-51144e6eb6a2', 'commune': 'Comuna 4 - Aranjuez', 'neighborhood': 'Brasilia', 'partition_date': '17062024', 'event_date': '17/06/2024 17:47:33', 'event_day': 17, 'event_hour': 17, 'event_minute': 47, 'event_month': 6, 'event_second': 33, 'event_year': 2024, 'current_temperature': 24.0}
# Enviado: {'latitude': 6.254579, 'longitude': -75.538353, 'date': '17/06/2024 17:47:34', 'customer_id': 1760, 'employee_id': 'Employee_47', 'quantity_products': 50, 'order_id': '3f8ef6fc-a869-4dcc-9827-209eb693fde9', 'commune': 'Comuna 8 - Villa Hermosa', 'neighborhood': 'Llanaditas', 'partition_date': '17062024', 'event_date': '17/06/2024 17:47:34', 'event_day': 17, 'event_hour': 17, 'event_minute': 47, 'event_month': 6, 'event_second': 34, 'event_year': 2024, 'current_temperature': 24.0}
# Enviado: {'latitude': 6.228153, 'longitude': -75.52915, 'date': '17/06/2024 17:47:35', 'customer_id': 1278, 'employee_id': 'Employee_185', 'quantity_products': 50, 'order_id': 'e85e9e70-37fb-4ea7-99d7-e3c1f938157a', 'commune': 'Comuna 9 - Buenos Aires', 'neighborhood': 'Ocho de Marzo', 'partition_date': '17062024', 'event_date': '17/06/2024 17:47:35', 'event_day': 17, 'event_hour': 17, 'event_minute': 47, 'event_month': 6, 'event_second': 35, 'event_year': 2024, 'current_temperature': 24.0}
# Enviado: {'latitude': 6.243445, 'longitude': -75.548496, 'date': '17/06/2024 17:47:36', 'customer_id': 1469, 'employee_id': 'Employee_25', 'quantity_products': 50, 'order_id': 'ad05b783-e0fe-4d2d-ab50-a8791cd9b7f6', 'commune': 'Comuna 8 - Villa Hermosa', 'neighborhood': 'El Pinal', 'partition_date': '17062024', 'event_date': '17/06/2024 17:47:36', 'event_day': 17, 'event_hour': 17, 'event_minute': 47, 'event_month': 6, 'event_second': 36, 'event_year': 2024, 'current_temperature': 24.0}
# Enviado: {'latitude': 6.233647, 'longitude': -75.560311, 'date': '17/06/2024 17:47:37', 'customer_id': 1965, 'employee_id': 'Employee_85', 'quantity_products': 50, 'order_id': '8975e3ba-16fa-4cb4-9204-57bfd6f80262', 'commune': 'Comuna 9 - Buenos Aires', 'neighborhood': 'Loreto', 'partition_date': '17062024', 'event_date': '17/06/2024 17:47:37', 'event_day': 17, 'event_hour': 17, 'event_minute': 47, 'event_month': 6, 'event_second': 37, 'event_year': 2024, 'current_temperature': 24.0}
# Enviado: {'latitude': 6.301091, 'longitude': -75.548209, 'date': '17/06/2024 17:47:38', 'customer_id': 1144, 'employee_id': 'Employee_115', 'quantity_products': 39, 'order_id': '887f6773-d70a-4bdf-89fc-e9d5424b3f06', 'commune': 'Comuna 1 - Popular', 'neighborhood': 'Popular', 'partition_date': '17062024', 'event_date': '17/06/2024 17:47:38', 'event_day': 17, 'event_hour': 17, 'event_minute': 47, 'event_month': 6, 'event_second': 38, 'event_year': 2024, 'current_temperature': 24.0}
# Enviado: {'latitude': 6.235093, 'longitude': -75.557936, 'date': '17/06/2024 17:47:39', 'customer_id': 1478, 'employee_id': 'Employee_143', 'quantity_products': 43, 'order_id': '2e7e271d-81fb-4c8a-a8e0-7e015f7f6561', 'commune': 'Comuna 9 - Buenos Aires', 'neighborhood': 'Loreto', 'partition_date': '17062024', 'event_date': '17/06/2024 17:47:39', 'event_day': 17, 'event_hour': 17, 'event_minute': 47, 'event_month': 6, 'event_second': 39, 'event_year': 2024, 'current_temperature': 24.0}
# Enviado: {'latitude': 6.299064, 'longitude': -75.545337, 'date': '17/06/2024 17:47:40', 'customer_id': 1145, 'employee_id': 'Employee_13', 'quantity_products': 50, 'order_id': '2d5babe4-c6c0-4417-bdb2-0d5e4344aa00', 'commune': 'Comuna 1 - Popular', 'neighborhood': 'Santo Domingo Savio No.1', 'partition_date': '17062024', 'event_date': '17/06/2024 17:47:40', 'event_day': 17, 'event_hour': 17, 'event_minute': 47, 'event_month': 6, 'event_second': 40, 'event_year': 2024, 'current_temperature': 24.0}
# Enviado: {'latitude': 6.297461, 'longitude': -75.557846, 'date': '17/06/2024 17:47:41', 'customer_id': 1805, 'employee_id': 'Employee_3', 'quantity_products': 50, 'order_id': '7d2fe19a-43d5-4c2b-b301-c47c5f2f1db0', 'commune': 'Comuna 2 - Santa Cruz', 'neighborhood': 'Santa Cruz', 'partition_date': '17062024', 'event_date': '17/06/2024 17:47:41', 'event_day': 17, 'event_hour': 17, 'event_minute': 47, 'event_month': 6, 'event_second': 41, 'event_year': 2024, 'current_temperature': 24.0}
# Enviado: {'latitude': 6.252831, 'longitude': -75.565694, 'date': '17/06/2024 17:47:42', 'customer_id': 1977, 'employee_id': 'Employee_11', 'quantity_products': 35, 'order_id': '59c45649-2fa8-4545-87b1-5c34c6bed479', 'commune': 'Comuna 10 - La Candelaria', 'neighborhood': 'Villa Nueva', 'partition_date': '17062024', 'event_date': '17/06/2024 17:47:42', 'event_day': 17, 'event_hour': 17, 'event_minute': 47, 'event_month': 6, 'event_second': 42, 'event_year': 2024, 'current_temperature': 24.0}
# Enviado: {'latitude': 6.271556, 'longitude': -75.54339, 'date': '17/06/2024 17:47:43', 'customer_id': 1720, 'employee_id': 'Employee_155', 'quantity_products': 50, 'order_id': 'c8168af1-d69f-4413-8f7b-319e661e99c7', 'commune': 'Comuna 3 - Manrique', 'neighborhood': 'La Cruz', 'partition_date': '17062024', 'event_date': '17/06/2024 17:47:43', 'event_day': 17, 'event_hour': 17, 'event_minute': 47, 'event_month': 6, 'event_second': 43, 'event_year': 2024, 'current_temperature': 24.0}
# Enviado: {'latitude': 6.269597, 'longitude': -75.531581, 'date': '17/06/2024 17:47:45', 'customer_id': 1394, 'employee_id': 'Employee_17', 'quantity_products': 50, 'order_id': '112fe1ec-7d61-4053-9be6-cf73d8d43af4', 'commune': 'Comuna 3 - Manrique', 'neighborhood': 'La Cruz', 'partition_date': '17062024', 'event_date': '17/06/2024 17:47:45', 'event_day': 17, 'event_hour': 17, 'event_minute': 47, 'event_month': 6, 'event_second': 45, 'event_year': 2024, 'current_temperature': 24.0}
