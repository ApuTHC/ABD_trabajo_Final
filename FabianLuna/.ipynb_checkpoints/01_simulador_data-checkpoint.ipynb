# %% [markdown]
# # Librerías

# %%
# pip install geopy

# %%
# pip install meteostat

# %%
import json
import time
import uuid
import random
from datetime import datetime, timedelta
import pytz
from geopy.geocoders import Nominatim
from meteostat import Point, Hourly
# employees = {i: (f"{i+1}", f"{i+101}") for i in range(100)}

# %%
# Definir las coordenadas aproximadas de Medellín
lat_range = (6.217, 6.317)  # Latitud de Medellín
lon_range = (-75.567, -75.467)  # Longitud de Medellín

# Inicializar el geolocalizador
geolocator = Nominatim(user_agent="medellin_locator")

# %% [markdown]
# # Obtención de datos

# %%
# Cargar puntos de venta válidos desde el archivo JSON
with open('valid_points.json', 'r') as file:
    points_of_sale = json.load(file)

# Generar 200 empleados, 2 por cada punto de venta
employees = {i: (f"Employee_{i*2+1}", f"Employee_{i*2+2}") for i in range(100)}

# Inicializar el geolocalizador
geolocator = Nominatim(user_agent="medellin_locator")

# Función para obtener la temperatura actual
def get_current_temperature(latitude, longitude):
    location = Point(latitude, longitude)
    start = datetime.now() - timedelta(hours=1)
    end = datetime.now()
    data = Hourly(location, start, end)
    data = data.fetch()
    temperature = data['temp'].mean() if not data.empty else 20  # Usar 20 como valor predeterminado si no hay datos
    return round(temperature, 1)

# Generar cantidad de productos en función de la temperatura
def generate_quantity_products(temperature):
    # Normalizar la temperatura entre un rango de 0 y 1
    temp_min, temp_max = 18, 24  # Rango de temperaturas en °C
    normalized_temp = (temperature - temp_min) / (temp_max - temp_min)
    
    # Generar la cantidad de productos basada en la temperatura normalizada
    min_quantity, max_quantity = 1, 50
    mean_quantity = normalized_temp * (max_quantity - min_quantity) + min_quantity
    
    # Añadir variabilidad a la cantidad de productos
    quantity = int(random.gauss(mean_quantity,10))  # Usar una desviación estándar de 10
    
    # Asegurar que la cantidad esté dentro del rango permitido
    return max(min(quantity, max_quantity), min_quantity)

# Generar datos simulados
def generate_event(pos_index):
    pos = points_of_sale[pos_index]
    worker = employees[pos_index]
    date_now = datetime.now(pytz.timezone('America/Bogota'))
    temperature = get_current_temperature(pos["latitude"], pos["longitude"])
    quantity_products = generate_quantity_products(temperature)
    
    event = {
        "latitude": pos["latitude"],
        "longitude": pos["longitude"],
        "date": date_now.strftime("%d/%m/%Y %H:%M:%S"),
        "customer_id": random.randint(1000, 2000),
        "employee_id": worker[0] if date_now.weekday() < 5 else worker[1],  # Lunes a Viernes / Fines de Semana
        "quantity_products": quantity_products,
        "order_id": str(uuid.uuid4()),
        "commune": pos["commune"],
        "neighborhood": pos["neighborhood"],
        "partition_date": date_now.strftime("%d%m%Y"),
        "event_date": date_now.strftime("%d/%m/%Y %H:%M:%S"),
        "event_day": date_now.day,
        "event_hour": date_now.hour,
        "event_minute": date_now.minute,
        "event_month": date_now.month,
        "event_second": date_now.second,
        "event_year": date_now.year,
        "current_temperature": temperature
    }
    return event


# Enviar los datos
def send_data(s, conn, data):
    conn.sendall(json.dumps(data).encode() + b'\n')
    print("Enviado:", data)

# %% [markdown]
# # Socket

# %%
import socket

# %%
# Socket
def servidor():
    
    host = 'localhost'  # Nombre del host o dirección IP
    port = 2222  # Puerto en el que escucha el servidor

    s = socket.socket()
    s.bind((host, port))
    s.listen(1)
    print(f"Listening on {host}:{port}")
    
    conn, addr = s.accept()
    print(f"Connected from {addr}")
    
    try:
        while True:
            event = generate_event(random.randint(0, 99))
            # Esperar 30 segundos antes de generar el siguiente evento
            send_data(s, conn, event)
            # Guardado en un archivo JSON
            with open('simulated_data_00.json', 'a') as file:
                file.write(json.dumps(event) + "\n")
            
            time.sleep(1)
            
    except KeyboardInterrupt:
        print("Stopping the connection ...")
        conn.close()
        s.close()
        print("Connection stopped.")
    
    except BrokenPipeError:
        print("The connection has been closed.")
        conn.close()
        s.close()

if __name__ == "__main__":
    servidor()
# Out:
# Listening on localhost:2222
# Connected from ('127.0.0.1', 57566)
# Enviado: {'latitude': 6.255342, 'longitude': -75.555875, 'date': '17/06/2024 15:46:53', 'customer_id': 1885, 'employee_id': 'Employee_157', 'quantity_products': 50, 'order_id': '86ccee36-6bd2-4c3b-981f-13270e943516', 'commune': 'Comuna 8 - Villa Hermosa', 'neighborhood': 'San Miguel', 'partition_date': '17062024', 'event_date': '17/06/2024 15:46:53', 'event_day': 17, 'event_hour': 15, 'event_minute': 46, 'event_month': 6, 'event_second': 53, 'event_year': 2024, 'current_temperature': 25.9}
# Enviado: {'latitude': 6.299954, 'longitude': -75.559406, 'date': '17/06/2024 15:46:56', 'customer_id': 1185, 'employee_id': 'Employee_141', 'quantity_products': 50, 'order_id': '459d17cb-92c9-45bd-a9c2-94dc743e734c', 'commune': 'Comuna 5 - Castilla', 'neighborhood': 'Héctor Abad Gómez', 'partition_date': '17062024', 'event_date': '17/06/2024 15:46:56', 'event_day': 17, 'event_hour': 15, 'event_minute': 46, 'event_month': 6, 'event_second': 56, 'event_year': 2024, 'current_temperature': 25.9}
# Enviado: {'latitude': 6.233554, 'longitude': -75.565071, 'date': '17/06/2024 15:46:57', 'customer_id': 1438, 'employee_id': 'Employee_129', 'quantity_products': 50, 'order_id': '3a360181-2401-4034-a9da-c774b0485041', 'commune': 'Comuna 10 - La Candelaria', 'neighborhood': 'Barrio San Diego', 'partition_date': '17062024', 'event_date': '17/06/2024 15:46:57', 'event_day': 17, 'event_hour': 15, 'event_minute': 46, 'event_month': 6, 'event_second': 57, 'event_year': 2024, 'current_temperature': 25.9}
# Enviado: {'latitude': 6.233505, 'longitude': -75.539321, 'date': '17/06/2024 15:46:58', 'customer_id': 1857, 'employee_id': 'Employee_103', 'quantity_products': 50, 'order_id': '07b6751e-74d2-4441-a520-917afabd7873', 'commune': 'Comuna 8 - Villa Hermosa', 'neighborhood': 'Villa Tina', 'partition_date': '17062024', 'event_date': '17/06/2024 15:46:58', 'event_day': 17, 'event_hour': 15, 'event_minute': 46, 'event_month': 6, 'event_second': 58, 'event_year': 2024, 'current_temperature': 25.9}
# Enviado: {'latitude': 6.250895, 'longitude': -75.564412, 'date': '17/06/2024 15:46:59', 'customer_id': 1211, 'employee_id': 'Employee_193', 'quantity_products': 50, 'order_id': 'a267b3c0-2794-4163-aba8-35b3a3de717e', 'commune': 'Comuna 10 - La Candelaria', 'neighborhood': 'La Candelaria', 'partition_date': '17062024', 'event_date': '17/06/2024 15:46:59', 'event_day': 17, 'event_hour': 15, 'event_minute': 46, 'event_month': 6, 'event_second': 59, 'event_year': 2024, 'current_temperature': 25.9}
# Enviado: {'latitude': 6.229935, 'longitude': -75.556966, 'date': '17/06/2024 15:47:00', 'customer_id': 1982, 'employee_id': 'Employee_165', 'quantity_products': 50, 'order_id': '57d15876-fbe6-4a3c-9ace-5350a2f77a00', 'commune': 'Comuna 9 - Buenos Aires', 'neighborhood': 'Loreto', 'partition_date': '17062024', 'event_date': '17/06/2024 15:47:00', 'event_day': 17, 'event_hour': 15, 'event_minute': 47, 'event_month': 6, 'event_second': 0, 'event_year': 2024, 'current_temperature': 25.9}
# Enviado: {'latitude': 6.233505, 'longitude': -75.539321, 'date': '17/06/2024 15:47:01', 'customer_id': 1721, 'employee_id': 'Employee_103', 'quantity_products': 50, 'order_id': '577fe3dc-6675-4ddb-a777-6f7fb54cdc1b', 'commune': 'Comuna 8 - Villa Hermosa', 'neighborhood': 'Villa Tina', 'partition_date': '17062024', 'event_date': '17/06/2024 15:47:01', 'event_day': 17, 'event_hour': 15, 'event_minute': 47, 'event_month': 6, 'event_second': 1, 'event_year': 2024, 'current_temperature': 25.9}
# Enviado: {'latitude': 6.22393, 'longitude': -75.540527, 'date': '17/06/2024 15:47:02', 'customer_id': 1088, 'employee_id': 'Employee_121', 'quantity_products': 50, 'order_id': '8bd9fc40-6df1-4b4e-9a02-17b0e4b560d8', 'commune': 'Comuna 9 - Buenos Aires', 'neighborhood': 'Bomboná No. 2', 'partition_date': '17062024', 'event_date': '17/06/2024 15:47:02', 'event_day': 17, 'event_hour': 15, 'event_minute': 47, 'event_month': 6, 'event_second': 2, 'event_year': 2024, 'current_temperature': 25.9}
# Enviado: {'latitude': 6.231786, 'longitude': -75.538967, 'date': '17/06/2024 15:47:03', 'customer_id': 1410, 'employee_id': 'Employee_173', 'quantity_products': 50, 'order_id': '2845d479-8fa5-4764-bb7b-d2ebdc6b2782', 'commune': 'Comuna 9 - Buenos Aires', 'neighborhood': 'Barrios de Jesús', 'partition_date': '17062024', 'event_date': '17/06/2024 15:47:03', 'event_day': 17, 'event_hour': 15, 'event_minute': 47, 'event_month': 6, 'event_second': 3, 'event_year': 2024, 'current_temperature': 25.9}
# Enviado: {'latitude': 6.228902, 'longitude': -75.53913, 'date': '17/06/2024 15:47:04', 'customer_id': 1937, 'employee_id': 'Employee_109', 'quantity_products': 50, 'order_id': '776c9e2a-3ddc-4632-9e9e-0fc67d9dd1ee', 'commune': 'Comuna 9 - Buenos Aires', 'neighborhood': 'Barrios de Jesús', 'partition_date': '17062024', 'event_date': '17/06/2024 15:47:04', 'event_day': 17, 'event_hour': 15, 'event_minute': 47, 'event_month': 6, 'event_second': 4, 'event_year': 2024, 'current_temperature': 25.9}
# Enviado: {'latitude': 6.302827, 'longitude': -75.560455, 'date': '17/06/2024 15:47:05', 'customer_id': 1261, 'employee_id': 'Employee_63', 'quantity_products': 50, 'order_id': '58f22cd7-6228-4f41-a645-165c3f904451', 'commune': 'Comuna 5 - Castilla', 'neighborhood': 'Héctor Abad Gómez', 'partition_date': '17062024', 'event_date': '17/06/2024 15:47:05', 'event_day': 17, 'event_hour': 15, 'event_minute': 47, 'event_month': 6, 'event_second': 5, 'event_year': 2024, 'current_temperature': 25.9}
# Enviado: {'latitude': 6.295457, 'longitude': -75.557531, 'date': '17/06/2024 15:47:06', 'customer_id': 1555, 'employee_id': 'Employee_127', 'quantity_products': 50, 'order_id': '0248ffcf-fa12-4239-907b-312d640a61d0', 'commune': 'Comuna 2 - Santa Cruz', 'neighborhood': 'Santa Cruz', 'partition_date': '17062024', 'event_date': '17/06/2024 15:47:06', 'event_day': 17, 'event_hour': 15, 'event_minute': 47, 'event_month': 6, 'event_second': 6, 'event_year': 2024, 'current_temperature': 25.9}
# Enviado: {'latitude': 6.272453, 'longitude': -75.542127, 'date': '17/06/2024 15:47:07', 'customer_id': 1819, 'employee_id': 'Employee_139', 'quantity_products': 50, 'order_id': '957f51e9-c4bd-4da2-a0cf-1202075bf889', 'commune': 'Comuna 3 - Manrique', 'neighborhood': 'Oriente', 'partition_date': '17062024', 'event_date': '17/06/2024 15:47:07', 'event_day': 17, 'event_hour': 15, 'event_minute': 47, 'event_month': 6, 'event_second': 7, 'event_year': 2024, 'current_temperature': 25.9}
# Enviado: {'latitude': 6.233249, 'longitude': -75.544511, 'date': '17/06/2024 15:47:08', 'customer_id': 1772, 'employee_id': 'Employee_153', 'quantity_products': 50, 'order_id': 'b9de1213-eb18-4dc8-80af-417c52f5d257', 'commune': 'Comuna 9 - Buenos Aires', 'neighborhood': 'Los Cerros - El Vergel', 'partition_date': '17062024', 'event_date': '17/06/2024 15:47:08', 'event_day': 17, 'event_hour': 15, 'event_minute': 47, 'event_month': 6, 'event_second': 8, 'event_year': 2024, 'current_temperature': 25.9}
# Enviado: {'latitude': 6.241087, 'longitude': -75.54213, 'date': '17/06/2024 15:47:09', 'customer_id': 1437, 'employee_id': 'Employee_37', 'quantity_products': 50, 'order_id': '058e3161-3e70-4bf6-a96c-df03ba113e94', 'commune': 'Comuna 8 - Villa Hermosa', 'neighborhood': 'La Libertad', 'partition_date': '17062024', 'event_date': '17/06/2024 15:47:09', 'event_day': 17, 'event_hour': 15, 'event_minute': 47, 'event_month': 6, 'event_second': 9, 'event_year': 2024, 'current_temperature': 25.9}
# Enviado: {'latitude': 6.288678, 'longitude': -75.556225, 'date': '17/06/2024 15:47:10', 'customer_id': 1120, 'employee_id': 'Employee_135', 'quantity_products': 50, 'order_id': '0cd83189-241c-40b7-a47f-2ceeff25ded6', 'commune': 'Comuna 4 - Aranjuez', 'neighborhood': 'Berlin', 'partition_date': '17062024', 'event_date': '17/06/2024 15:47:10', 'event_day': 17, 'event_hour': 15, 'event_minute': 47, 'event_month': 6, 'event_second': 10, 'event_year': 2024, 'current_temperature': 25.9}
# Enviado: {'latitude': 6.268129, 'longitude': -75.532389, 'date': '17/06/2024 15:47:11', 'customer_id': 1884, 'employee_id': 'Employee_73', 'quantity_products': 50, 'order_id': 'cefb9fe7-6a4d-4362-ae3a-b6a226bcff1d', 'commune': 'Comuna 3 - Manrique', 'neighborhood': 'La Cruz', 'partition_date': '17062024', 'event_date': '17/06/2024 15:47:11', 'event_day': 17, 'event_hour': 15, 'event_minute': 47, 'event_month': 6, 'event_second': 11, 'event_year': 2024, 'current_temperature': 25.9}
# Enviado: {'latitude': 6.298354, 'longitude': -75.564556, 'date': '17/06/2024 15:47:12', 'customer_id': 1063, 'employee_id': 'Employee_71', 'quantity_products': 50, 'order_id': 'dd95d98e-2a39-402a-8771-796804c396b3', 'commune': 'Comuna 5 - Castilla', 'neighborhood': 'Villa Niza', 'partition_date': '17062024', 'event_date': '17/06/2024 15:47:12', 'event_day': 17, 'event_hour': 15, 'event_minute': 47, 'event_month': 6, 'event_second': 12, 'event_year': 2024, 'current_temperature': 25.9}
# Enviado: {'latitude': 6.241087, 'longitude': -75.54213, 'date': '17/06/2024 15:47:13', 'customer_id': 1874, 'employee_id': 'Employee_37', 'quantity_products': 50, 'order_id': '9e27c186-a010-4bc1-8906-1cf0c2a40147', 'commune': 'Comuna 8 - Villa Hermosa', 'neighborhood': 'La Libertad', 'partition_date': '17062024', 'event_date': '17/06/2024 15:47:13', 'event_day': 17, 'event_hour': 15, 'event_minute': 47, 'event_month': 6, 'event_second': 13, 'event_year': 2024, 'current_temperature': 25.9}
# Enviado: {'latitude': 6.251305, 'longitude': -75.539935, 'date': '17/06/2024 15:47:14', 'customer_id': 1766, 'employee_id': 'Employee_95', 'quantity_products': 50, 'order_id': '6de2e334-c5ce-4896-83b5-dcd5548d2b3b', 'commune': 'Comuna 8 - Villa Hermosa', 'neighborhood': 'Llanaditas', 'partition_date': '17062024', 'event_date': '17/06/2024 15:47:14', 'event_day': 17, 'event_hour': 15, 'event_minute': 47, 'event_month': 6, 'event_second': 14, 'event_year': 2024, 'current_temperature': 25.9}
# Enviado: {'latitude': 6.273109, 'longitude': -75.563901, 'date': '17/06/2024 15:47:15', 'customer_id': 1263, 'employee_id': 'Employee_5', 'quantity_products': 49, 'order_id': '109d0fbd-d399-4c56-89a1-5644237cc71b', 'commune': 'Comuna 4 - Aranjuez', 'neighborhood': 'Miranda', 'partition_date': '17062024', 'event_date': '17/06/2024 15:47:15', 'event_day': 17, 'event_hour': 15, 'event_minute': 47, 'event_month': 6, 'event_second': 15, 'event_year': 2024, 'current_temperature': 25.9}
# Enviado: {'latitude': 6.251305, 'longitude': -75.539935, 'date': '17/06/2024 15:47:16', 'customer_id': 1344, 'employee_id': 'Employee_95', 'quantity_products': 50, 'order_id': 'b67db311-937c-4411-b9da-8352681ef38a', 'commune': 'Comuna 8 - Villa Hermosa', 'neighborhood': 'Llanaditas', 'partition_date': '17062024', 'event_date': '17/06/2024 15:47:16', 'event_day': 17, 'event_hour': 15, 'event_minute': 47, 'event_month': 6, 'event_second': 16, 'event_year': 2024, 'current_temperature': 25.9}
# Enviado: {'latitude': 6.263214, 'longitude': -75.565651, 'date': '17/06/2024 15:47:17', 'customer_id': 1590, 'employee_id': 'Employee_117', 'quantity_products': 50, 'order_id': 'dd4e674a-40b9-42d6-acfd-e5d71e66403d', 'commune': 'Comuna 10 - La Candelaria', 'neighborhood': 'Prado', 'partition_date': '17062024', 'event_date': '17/06/2024 15:47:17', 'event_day': 17, 'event_hour': 15, 'event_minute': 47, 'event_month': 6, 'event_second': 17, 'event_year': 2024, 'current_temperature': 25.9}
# Enviado: {'latitude': 6.252563, 'longitude': -75.538641, 'date': '17/06/2024 15:47:19', 'customer_id': 1872, 'employee_id': 'Employee_89', 'quantity_products': 50, 'order_id': '4cb604cf-7093-4cb3-bc12-255cd8a4b275', 'commune': 'Comuna 8 - Villa Hermosa', 'neighborhood': 'Llanaditas', 'partition_date': '17062024', 'event_date': '17/06/2024 15:47:19', 'event_day': 17, 'event_hour': 15, 'event_minute': 47, 'event_month': 6, 'event_second': 19, 'event_year': 2024, 'current_temperature': 25.9}
# Enviado: {'latitude': 6.274861, 'longitude': -75.533979, 'date': '17/06/2024 15:47:20', 'customer_id': 1309, 'employee_id': 'Employee_161', 'quantity_products': 50, 'order_id': '11f51381-9da4-4132-bec7-9956e8982f2e', 'commune': 'Comuna 3 - Manrique', 'neighborhood': 'La Cruz', 'partition_date': '17062024', 'event_date': '17/06/2024 15:47:20', 'event_day': 17, 'event_hour': 15, 'event_minute': 47, 'event_month': 6, 'event_second': 20, 'event_year': 2024, 'current_temperature': 25.9}
# Enviado: {'latitude': 6.26349, 'longitude': -75.533003, 'date': '17/06/2024 15:47:21', 'customer_id': 1274, 'employee_id': 'Employee_19', 'quantity_products': 50, 'order_id': 'a4e22805-c387-4d4c-ae4d-aa751921c52a', 'commune': 'Comuna 3 - Manrique', 'neighborhood': 'Versalles No. 2', 'partition_date': '17062024', 'event_date': '17/06/2024 15:47:21', 'event_day': 17, 'event_hour': 15, 'event_minute': 47, 'event_month': 6, 'event_second': 21, 'event_year': 2024, 'current_temperature': 25.9}
# Enviado: {'latitude': 6.295158, 'longitude': -75.550459, 'date': '17/06/2024 15:47:22', 'customer_id': 1768, 'employee_id': 'Employee_181', 'quantity_products': 50, 'order_id': '09f0ac39-0662-48dc-9239-b08c05cf5032', 'commune': 'Comuna 2 - Santa Cruz', 'neighborhood': 'Villa del Socorro', 'partition_date': '17062024', 'event_date': '17/06/2024 15:47:22', 'event_day': 17, 'event_hour': 15, 'event_minute': 47, 'event_month': 6, 'event_second': 22, 'event_year': 2024, 'current_temperature': 25.9}
# Enviado: {'latitude': 6.301091, 'longitude': -75.548209, 'date': '17/06/2024 15:47:23', 'customer_id': 1431, 'employee_id': 'Employee_115', 'quantity_products': 50, 'order_id': 'cfc45f58-1186-4800-8e15-d5e576a56514', 'commune': 'Comuna 1 - Popular', 'neighborhood': 'Popular', 'partition_date': '17062024', 'event_date': '17/06/2024 15:47:23', 'event_day': 17, 'event_hour': 15, 'event_minute': 47, 'event_month': 6, 'event_second': 23, 'event_year': 2024, 'current_temperature': 25.9}
# Enviado: {'latitude': 6.230978, 'longitude': -75.533582, 'date': '17/06/2024 15:47:24', 'customer_id': 1762, 'employee_id': 'Employee_9', 'quantity_products': 50, 'order_id': '2f31c00d-0fd6-49b2-8b52-f5066aa39b32', 'commune': 'Comuna 9 - Buenos Aires', 'neighborhood': 'Barrios de Jesús', 'partition_date': '17062024', 'event_date': '17/06/2024 15:47:24', 'event_day': 17, 'event_hour': 15, 'event_minute': 47, 'event_month': 6, 'event_second': 24, 'event_year': 2024, 'current_temperature': 25.9}
# Enviado: {'latitude': 6.273109, 'longitude': -75.563901, 'date': '17/06/2024 15:47:25', 'customer_id': 1389, 'employee_id': 'Employee_5', 'quantity_products': 50, 'order_id': '8310c55e-f939-482a-9f5f-56ec0589f653', 'commune': 'Comuna 4 - Aranjuez', 'neighborhood': 'Miranda', 'partition_date': '17062024', 'event_date': '17/06/2024 15:47:25', 'event_day': 17, 'event_hour': 15, 'event_minute': 47, 'event_month': 6, 'event_second': 25, 'event_year': 2024, 'current_temperature': 25.9}
# Enviado: {'latitude': 6.300545, 'longitude': -75.563593, 'date': '17/06/2024 15:47:26', 'customer_id': 1042, 'employee_id': 'Employee_179', 'quantity_products': 50, 'order_id': '1933eff0-460d-4443-a554-dfe53f5fa884', 'commune': 'Comuna 5 - Castilla', 'neighborhood': 'Boyacá', 'partition_date': '17062024', 'event_date': '17/06/2024 15:47:26', 'event_day': 17, 'event_hour': 15, 'event_minute': 47, 'event_month': 6, 'event_second': 26, 'event_year': 2024, 'current_temperature': 25.9}
# Enviado: {'latitude': 6.231786, 'longitude': -75.538967, 'date': '17/06/2024 15:47:27', 'customer_id': 1663, 'employee_id': 'Employee_173', 'quantity_products': 50, 'order_id': '6b0f12e6-0dea-4a7a-b697-21804604da64', 'commune': 'Comuna 9 - Buenos Aires', 'neighborhood': 'Barrios de Jesús', 'partition_date': '17062024', 'event_date': '17/06/2024 15:47:27', 'event_day': 17, 'event_hour': 15, 'event_minute': 47, 'event_month': 6, 'event_second': 27, 'event_year': 2024, 'current_temperature': 25.9}
# Enviado: {'latitude': 6.30199, 'longitude': -75.565785, 'date': '17/06/2024 15:47:28', 'customer_id': 1223, 'employee_id': 'Employee_39', 'quantity_products': 50, 'order_id': '1c417f17-d62c-47cc-9adc-2ccaebf65059', 'commune': 'Comuna 5 - Castilla', 'neighborhood': 'Boyacá', 'partition_date': '17062024', 'event_date': '17/06/2024 15:47:28', 'event_day': 17, 'event_hour': 15, 'event_minute': 47, 'event_month': 6, 'event_second': 28, 'event_year': 2024, 'current_temperature': 25.9}
# Enviado: {'latitude': 6.274861, 'longitude': -75.533979, 'date': '17/06/2024 15:47:29', 'customer_id': 1087, 'employee_id': 'Employee_161', 'quantity_products': 50, 'order_id': 'd288391b-bae5-4d83-9c7a-32a333edc7b5', 'commune': 'Comuna 3 - Manrique', 'neighborhood': 'La Cruz', 'partition_date': '17062024', 'event_date': '17/06/2024 15:47:29', 'event_day': 17, 'event_hour': 15, 'event_minute': 47, 'event_month': 6, 'event_second': 29, 'event_year': 2024, 'current_temperature': 25.9}
# Enviado: {'latitude': 6.300545, 'longitude': -75.563593, 'date': '17/06/2024 15:47:30', 'customer_id': 1177, 'employee_id': 'Employee_179', 'quantity_products': 50, 'order_id': 'd40f46b1-f16a-45c6-9775-e47ce342bce8', 'commune': 'Comuna 5 - Castilla', 'neighborhood': 'Boyacá', 'partition_date': '17062024', 'event_date': '17/06/2024 15:47:30', 'event_day': 17, 'event_hour': 15, 'event_minute': 47, 'event_month': 6, 'event_second': 30, 'event_year': 2024, 'current_temperature': 25.9}
# Enviado: {'latitude': 6.26349, 'longitude': -75.533003, 'date': '17/06/2024 15:47:31', 'customer_id': 1554, 'employee_id': 'Employee_19', 'quantity_products': 50, 'order_id': '91d50224-a581-4cec-864f-7b636372a1ad', 'commune': 'Comuna 3 - Manrique', 'neighborhood': 'Versalles No. 2', 'partition_date': '17062024', 'event_date': '17/06/2024 15:47:31', 'event_day': 17, 'event_hour': 15, 'event_minute': 47, 'event_month': 6, 'event_second': 31, 'event_year': 2024, 'current_temperature': 25.9}
# Enviado: {'latitude': 6.237547, 'longitude': -75.536549, 'date': '17/06/2024 15:47:32', 'customer_id': 1421, 'employee_id': 'Employee_23', 'quantity_products': 50, 'order_id': '062e8851-61f8-4dc5-bd16-15e53024fc5a', 'commune': 'Comuna 8 - Villa Hermosa', 'neighborhood': 'San Antonio', 'partition_date': '17062024', 'event_date': '17/06/2024 15:47:32', 'event_day': 17, 'event_hour': 15, 'event_minute': 47, 'event_month': 6, 'event_second': 32, 'event_year': 2024, 'current_temperature': 25.9}
# Enviado: {'latitude': 6.256769, 'longitude': -75.53969, 'date': '17/06/2024 15:47:33', 'customer_id': 1858, 'employee_id': 'Employee_183', 'quantity_products': 50, 'order_id': 'cef8cce5-be8b-4cb8-a997-3d37fc7a32ad', 'commune': 'Comuna 8 - Villa Hermosa', 'neighborhood': 'Llanaditas', 'partition_date': '17062024', 'event_date': '17/06/2024 15:47:33', 'event_day': 17, 'event_hour': 15, 'event_minute': 47, 'event_month': 6, 'event_second': 33, 'event_year': 2024, 'current_temperature': 25.9}
# Enviado: {'latitude': 6.217431, 'longitude': -75.528292, 'date': '17/06/2024 15:47:34', 'customer_id': 1200, 'employee_id': 'Employee_79', 'quantity_products': 50, 'order_id': 'eeb98df2-3d7a-44d5-9a24-6b12f93c0f49', 'commune': 'Comuna 9 - Buenos Aires', 'neighborhood': 'Ocho de Marzo', 'partition_date': '17062024', 'event_date': '17/06/2024 15:47:34', 'event_day': 17, 'event_hour': 15, 'event_minute': 47, 'event_month': 6, 'event_second': 34, 'event_year': 2024, 'current_temperature': 25.9}
# Enviado: {'latitude': 6.237547, 'longitude': -75.536549, 'date': '17/06/2024 15:47:35', 'customer_id': 1730, 'employee_id': 'Employee_23', 'quantity_products': 50, 'order_id': 'a7942c43-50ca-4f4b-b72d-a2e78fc9bce7', 'commune': 'Comuna 8 - Villa Hermosa', 'neighborhood': 'San Antonio', 'partition_date': '17062024', 'event_date': '17/06/2024 15:47:35', 'event_day': 17, 'event_hour': 15, 'event_minute': 47, 'event_month': 6, 'event_second': 35, 'event_year': 2024, 'current_temperature': 25.9}
# Enviado: {'latitude': 6.230866, 'longitude': -75.530405, 'date': '17/06/2024 15:47:36', 'customer_id': 1218, 'employee_id': 'Employee_81', 'quantity_products': 50, 'order_id': '609c02a0-4e9c-4306-8174-c8b72d107833', 'commune': 'Comuna 8 - Villa Hermosa', 'neighborhood': 'Las Estancias', 'partition_date': '17062024', 'event_date': '17/06/2024 15:47:36', 'event_day': 17, 'event_hour': 15, 'event_minute': 47, 'event_month': 6, 'event_second': 36, 'event_year': 2024, 'current_temperature': 25.9}
# Enviado: {'latitude': 6.26349, 'longitude': -75.533003, 'date': '17/06/2024 15:47:37', 'customer_id': 1269, 'employee_id': 'Employee_19', 'quantity_products': 50, 'order_id': '6ae8fd1e-c648-4325-a5f7-257352c33884', 'commune': 'Comuna 3 - Manrique', 'neighborhood': 'Versalles No. 2', 'partition_date': '17062024', 'event_date': '17/06/2024 15:47:37', 'event_day': 17, 'event_hour': 15, 'event_minute': 47, 'event_month': 6, 'event_second': 37, 'event_year': 2024, 'current_temperature': 25.9}
# Enviado: {'latitude': 6.229935, 'longitude': -75.556966, 'date': '17/06/2024 15:47:38', 'customer_id': 1856, 'employee_id': 'Employee_165', 'quantity_products': 50, 'order_id': '9dd56078-15fe-4ed1-a3f5-0e10b577d127', 'commune': 'Comuna 9 - Buenos Aires', 'neighborhood': 'Loreto', 'partition_date': '17062024', 'event_date': '17/06/2024 15:47:38', 'event_day': 17, 'event_hour': 15, 'event_minute': 47, 'event_month': 6, 'event_second': 38, 'event_year': 2024, 'current_temperature': 25.9}
# Enviado: {'latitude': 6.302827, 'longitude': -75.560455, 'date': '17/06/2024 15:47:39', 'customer_id': 1598, 'employee_id': 'Employee_63', 'quantity_products': 50, 'order_id': '48beaaef-d490-47fb-86c4-c6feec92ee7b', 'commune': 'Comuna 5 - Castilla', 'neighborhood': 'Héctor Abad Gómez', 'partition_date': '17062024', 'event_date': '17/06/2024 15:47:39', 'event_day': 17, 'event_hour': 15, 'event_minute': 47, 'event_month': 6, 'event_second': 39, 'event_year': 2024, 'current_temperature': 25.9}
# Enviado: {'latitude': 6.26349, 'longitude': -75.533003, 'date': '17/06/2024 15:47:40', 'customer_id': 1383, 'employee_id': 'Employee_19', 'quantity_products': 50, 'order_id': 'f24c3e15-1e5f-4b50-8a36-26ab91fc47f8', 'commune': 'Comuna 3 - Manrique', 'neighborhood': 'Versalles No. 2', 'partition_date': '17062024', 'event_date': '17/06/2024 15:47:40', 'event_day': 17, 'event_hour': 15, 'event_minute': 47, 'event_month': 6, 'event_second': 40, 'event_year': 2024, 'current_temperature': 25.9}
# Enviado: {'latitude': 6.268129, 'longitude': -75.532389, 'date': '17/06/2024 15:47:42', 'customer_id': 1220, 'employee_id': 'Employee_73', 'quantity_products': 50, 'order_id': 'e894c7ff-be17-4405-aaa0-0aeda128c64d', 'commune': 'Comuna 3 - Manrique', 'neighborhood': 'La Cruz', 'partition_date': '17062024', 'event_date': '17/06/2024 15:47:42', 'event_day': 17, 'event_hour': 15, 'event_minute': 47, 'event_month': 6, 'event_second': 42, 'event_year': 2024, 'current_temperature': 25.9}
# Enviado: {'latitude': 6.240547, 'longitude': -75.537934, 'date': '17/06/2024 15:47:43', 'customer_id': 1716, 'employee_id': 'Employee_75', 'quantity_products': 50, 'order_id': '9e42ca24-1d67-4f4b-a261-0c43fcfe59e7', 'commune': 'Comuna 8 - Villa Hermosa', 'neighborhood': 'Villa Tina', 'partition_date': '17062024', 'event_date': '17/06/2024 15:47:43', 'event_day': 17, 'event_hour': 15, 'event_minute': 47, 'event_month': 6, 'event_second': 43, 'event_year': 2024, 'current_temperature': 25.9}
# Enviado: {'latitude': 6.268129, 'longitude': -75.532389, 'date': '17/06/2024 15:47:44', 'customer_id': 1357, 'employee_id': 'Employee_73', 'quantity_products': 50, 'order_id': 'c086a0da-0d9f-48f9-a23f-a50d7643bd36', 'commune': 'Comuna 3 - Manrique', 'neighborhood': 'La Cruz', 'partition_date': '17062024', 'event_date': '17/06/2024 15:47:44', 'event_day': 17, 'event_hour': 15, 'event_minute': 47, 'event_month': 6, 'event_second': 44, 'event_year': 2024, 'current_temperature': 25.9}
# Enviado: {'latitude': 6.250895, 'longitude': -75.564412, 'date': '17/06/2024 15:47:45', 'customer_id': 1956, 'employee_id': 'Employee_193', 'quantity_products': 50, 'order_id': '80f48483-bf4e-41ba-97f8-a5151b426558', 'commune': 'Comuna 10 - La Candelaria', 'neighborhood': 'La Candelaria', 'partition_date': '17062024', 'event_date': '17/06/2024 15:47:45', 'event_day': 17, 'event_hour': 15, 'event_minute': 47, 'event_month': 6, 'event_second': 45, 'event_year': 2024, 'current_temperature': 25.9}
# Enviado: {'latitude': 6.240851, 'longitude': -75.564423, 'date': '17/06/2024 15:47:46', 'customer_id': 1012, 'employee_id': 'Employee_91', 'quantity_products': 50, 'order_id': '259484bb-85c8-4528-93a3-85336f2eec72', 'commune': 'Comuna 10 - La Candelaria', 'neighborhood': 'Bomboná No. 1', 'partition_date': '17062024', 'event_date': '17/06/2024 15:47:46', 'event_day': 17, 'event_hour': 15, 'event_minute': 47, 'event_month': 6, 'event_second': 46, 'event_year': 2024, 'current_temperature': 25.9}
# Enviado: {'latitude': 6.26349, 'longitude': -75.533003, 'date': '17/06/2024 15:47:47', 'customer_id': 1890, 'employee_id': 'Employee_19', 'quantity_products': 50, 'order_id': 'c53fd077-dbb9-4dbf-bcf5-dc4ea19ecd80', 'commune': 'Comuna 3 - Manrique', 'neighborhood': 'Versalles No. 2', 'partition_date': '17062024', 'event_date': '17/06/2024 15:47:47', 'event_day': 17, 'event_hour': 15, 'event_minute': 47, 'event_month': 6, 'event_second': 47, 'event_year': 2024, 'current_temperature': 25.9}
# Enviado: {'latitude': 6.258068, 'longitude': -75.549198, 'date': '17/06/2024 15:47:48', 'customer_id': 1484, 'employee_id': 'Employee_171', 'quantity_products': 50, 'order_id': '0339f54c-b5b4-4c2c-986a-eef19c4c7187', 'commune': 'Comuna 8 - Villa Hermosa', 'neighborhood': 'Villa Hermosa', 'partition_date': '17062024', 'event_date': '17/06/2024 15:47:48', 'event_day': 17, 'event_hour': 15, 'event_minute': 47, 'event_month': 6, 'event_second': 48, 'event_year': 2024, 'current_temperature': 25.9}
# Enviado: {'latitude': 6.295457, 'longitude': -75.557531, 'date': '17/06/2024 15:47:49', 'customer_id': 1166, 'employee_id': 'Employee_127', 'quantity_products': 50, 'order_id': 'f69e6e1e-8cdd-4bb4-b3e3-f85fe751d672', 'commune': 'Comuna 2 - Santa Cruz', 'neighborhood': 'Santa Cruz', 'partition_date': '17062024', 'event_date': '17/06/2024 15:47:49', 'event_day': 17, 'event_hour': 15, 'event_minute': 47, 'event_month': 6, 'event_second': 49, 'event_year': 2024, 'current_temperature': 25.9}
# Enviado: {'latitude': 6.250895, 'longitude': -75.564412, 'date': '17/06/2024 15:47:50', 'customer_id': 1036, 'employee_id': 'Employee_193', 'quantity_products': 50, 'order_id': 'f3027f61-b3f2-47b0-9d22-9978b2dbb23c', 'commune': 'Comuna 10 - La Candelaria', 'neighborhood': 'La Candelaria', 'partition_date': '17062024', 'event_date': '17/06/2024 15:47:50', 'event_day': 17, 'event_hour': 15, 'event_minute': 47, 'event_month': 6, 'event_second': 50, 'event_year': 2024, 'current_temperature': 25.9}
# Enviado: {'latitude': 6.297461, 'longitude': -75.557846, 'date': '17/06/2024 15:47:51', 'customer_id': 1340, 'employee_id': 'Employee_3', 'quantity_products': 50, 'order_id': 'a6f1b98e-2f0c-43a8-81a8-3ce07c10d947', 'commune': 'Comuna 2 - Santa Cruz', 'neighborhood': 'Santa Cruz', 'partition_date': '17062024', 'event_date': '17/06/2024 15:47:51', 'event_day': 17, 'event_hour': 15, 'event_minute': 47, 'event_month': 6, 'event_second': 51, 'event_year': 2024, 'current_temperature': 25.9}
# Enviado: {'latitude': 6.271556, 'longitude': -75.54339, 'date': '17/06/2024 15:47:52', 'customer_id': 1955, 'employee_id': 'Employee_155', 'quantity_products': 50, 'order_id': '4b9fdc6e-c954-44a3-bb5e-d8403efe2de0', 'commune': 'Comuna 3 - Manrique', 'neighborhood': 'La Cruz', 'partition_date': '17062024', 'event_date': '17/06/2024 15:47:52', 'event_day': 17, 'event_hour': 15, 'event_minute': 47, 'event_month': 6, 'event_second': 52, 'event_year': 2024, 'current_temperature': 25.9}
# Enviado: {'latitude': 6.240547, 'longitude': -75.537934, 'date': '17/06/2024 15:47:53', 'customer_id': 1073, 'employee_id': 'Employee_75', 'quantity_products': 50, 'order_id': 'c4908e29-5977-4531-85b4-b2c2a3303fd9', 'commune': 'Comuna 8 - Villa Hermosa', 'neighborhood': 'Villa Tina', 'partition_date': '17062024', 'event_date': '17/06/2024 15:47:53', 'event_day': 17, 'event_hour': 15, 'event_minute': 47, 'event_month': 6, 'event_second': 53, 'event_year': 2024, 'current_temperature': 25.9}
# Enviado: {'latitude': 6.233572, 'longitude': -75.551487, 'date': '17/06/2024 15:47:54', 'customer_id': 1706, 'employee_id': 'Employee_145', 'quantity_products': 50, 'order_id': '5871451a-5734-4688-8894-8d0d3d6a16a6', 'commune': 'Comuna 9 - Buenos Aires', 'neighborhood': 'Cataluña', 'partition_date': '17062024', 'event_date': '17/06/2024 15:47:54', 'event_day': 17, 'event_hour': 15, 'event_minute': 47, 'event_month': 6, 'event_second': 54, 'event_year': 2024, 'current_temperature': 25.9}
# Enviado: {'latitude': 6.236339, 'longitude': -75.557067, 'date': '17/06/2024 15:47:55', 'customer_id': 1926, 'employee_id': 'Employee_29', 'quantity_products': 50, 'order_id': '5f98f53c-2a6c-4f02-90be-6ddcbd26dc0c', 'commune': 'Comuna 9 - Buenos Aires', 'neighborhood': 'Buenos Aires', 'partition_date': '17062024', 'event_date': '17/06/2024 15:47:55', 'event_day': 17, 'event_hour': 15, 'event_minute': 47, 'event_month': 6, 'event_second': 55, 'event_year': 2024, 'current_temperature': 25.9}
# Enviado: {'latitude': 6.298354, 'longitude': -75.564556, 'date': '17/06/2024 15:47:56', 'customer_id': 1699, 'employee_id': 'Employee_71', 'quantity_products': 50, 'order_id': 'a73978d6-17ae-4d3c-af0c-d3376532c3ad', 'commune': 'Comuna 5 - Castilla', 'neighborhood': 'Villa Niza', 'partition_date': '17062024', 'event_date': '17/06/2024 15:47:56', 'event_day': 17, 'event_hour': 15, 'event_minute': 47, 'event_month': 6, 'event_second': 56, 'event_year': 2024, 'current_temperature': 25.9}
# Enviado: {'latitude': 6.30199, 'longitude': -75.565785, 'date': '17/06/2024 15:47:57', 'customer_id': 1995, 'employee_id': 'Employee_39', 'quantity_products': 50, 'order_id': '0a45f03a-f786-4001-ae3a-12663341d2de', 'commune': 'Comuna 5 - Castilla', 'neighborhood': 'Boyacá', 'partition_date': '17062024', 'event_date': '17/06/2024 15:47:57', 'event_day': 17, 'event_hour': 15, 'event_minute': 47, 'event_month': 6, 'event_second': 57, 'event_year': 2024, 'current_temperature': 25.9}
# Enviado: {'latitude': 6.231588, 'longitude': -75.541907, 'date': '17/06/2024 15:47:58', 'customer_id': 1509, 'employee_id': 'Employee_105', 'quantity_products': 50, 'order_id': '230d02e3-07cc-491b-8b2b-5410c27f9158', 'commune': 'Comuna 9 - Buenos Aires', 'neighborhood': 'Bomboná No. 2', 'partition_date': '17062024', 'event_date': '17/06/2024 15:47:58', 'event_day': 17, 'event_hour': 15, 'event_minute': 47, 'event_month': 6, 'event_second': 58, 'event_year': 2024, 'current_temperature': 25.9}
# Enviado: {'latitude': 6.236339, 'longitude': -75.557067, 'date': '17/06/2024 15:47:59', 'customer_id': 1010, 'employee_id': 'Employee_29', 'quantity_products': 50, 'order_id': '48212ba6-469e-41ec-9dee-716846bf4b59', 'commune': 'Comuna 9 - Buenos Aires', 'neighborhood': 'Buenos Aires', 'partition_date': '17062024', 'event_date': '17/06/2024 15:47:59', 'event_day': 17, 'event_hour': 15, 'event_minute': 47, 'event_month': 6, 'event_second': 59, 'event_year': 2024, 'current_temperature': 25.9}
# Enviado: {'latitude': 6.255721, 'longitude': -75.560525, 'date': '17/06/2024 15:48:00', 'customer_id': 1805, 'employee_id': 'Employee_199', 'quantity_products': 50, 'order_id': '0bc913b4-9be5-470b-b1dd-f2b1464082c4', 'commune': 'Comuna 8 - Villa Hermosa', 'neighborhood': 'San Miguel', 'partition_date': '17062024', 'event_date': '17/06/2024 15:48:00', 'event_day': 17, 'event_hour': 15, 'event_minute': 48, 'event_month': 6, 'event_second': 0, 'event_year': 2024, 'current_temperature': 25.9}
# Enviado: {'latitude': 6.227021, 'longitude': -75.554104, 'date': '17/06/2024 15:48:01', 'customer_id': 1680, 'employee_id': 'Employee_159', 'quantity_products': 50, 'order_id': 'eeb7176e-28f3-4768-903f-f96e1513038a', 'commune': 'Comuna 9 - Buenos Aires', 'neighborhood': 'La Asomadera No. 3', 'partition_date': '17062024', 'event_date': '17/06/2024 15:48:01', 'event_day': 17, 'event_hour': 15, 'event_minute': 48, 'event_month': 6, 'event_second': 1, 'event_year': 2024, 'current_temperature': 25.9}
# Enviado: {'latitude': 6.248272, 'longitude': -75.536089, 'date': '17/06/2024 15:48:02', 'customer_id': 1599, 'employee_id': 'Employee_191', 'quantity_products': 50, 'order_id': 'be6f2ef5-27f6-4d6f-be1d-605dcb1a1789', 'commune': 'Comuna 8 - Villa Hermosa', 'neighborhood': 'Llanaditas', 'partition_date': '17062024', 'event_date': '17/06/2024 15:48:02', 'event_day': 17, 'event_hour': 15, 'event_minute': 48, 'event_month': 6, 'event_second': 2, 'event_year': 2024, 'current_temperature': 25.9}
# Enviado: {'latitude': 6.304733, 'longitude': -75.563183, 'date': '17/06/2024 15:48:03', 'customer_id': 1157, 'employee_id': 'Employee_55', 'quantity_products': 50, 'order_id': 'f130ae96-dc73-423e-9ba1-9b69dfe63cd9', 'commune': 'Comuna 5 - Castilla', 'neighborhood': 'Boyacá', 'partition_date': '17062024', 'event_date': '17/06/2024 15:48:03', 'event_day': 17, 'event_hour': 15, 'event_minute': 48, 'event_month': 6, 'event_second': 3, 'event_year': 2024, 'current_temperature': 25.9}
# Enviado: {'latitude': 6.231016, 'longitude': -75.531541, 'date': '17/06/2024 15:48:05', 'customer_id': 1991, 'employee_id': 'Employee_77', 'quantity_products': 50, 'order_id': '05a02562-35dd-4079-9d46-0eb8f4dc16e9', 'commune': 'Comuna 8 - Villa Hermosa', 'neighborhood': 'Las Estancias', 'partition_date': '17062024', 'event_date': '17/06/2024 15:48:05', 'event_day': 17, 'event_hour': 15, 'event_minute': 48, 'event_month': 6, 'event_second': 5, 'event_year': 2024, 'current_temperature': 25.9}
# Enviado: {'latitude': 6.233505, 'longitude': -75.539321, 'date': '17/06/2024 15:48:06', 'customer_id': 1341, 'employee_id': 'Employee_103', 'quantity_products': 50, 'order_id': '39494252-95cf-4324-9627-7f43e95b5725', 'commune': 'Comuna 8 - Villa Hermosa', 'neighborhood': 'Villa Tina', 'partition_date': '17062024', 'event_date': '17/06/2024 15:48:06', 'event_day': 17, 'event_hour': 15, 'event_minute': 48, 'event_month': 6, 'event_second': 6, 'event_year': 2024, 'current_temperature': 25.9}
# Enviado: {'latitude': 6.237547, 'longitude': -75.536549, 'date': '17/06/2024 15:48:07', 'customer_id': 1908, 'employee_id': 'Employee_23', 'quantity_products': 50, 'order_id': '8661942f-36b6-4255-b3d6-c6341a8cf41d', 'commune': 'Comuna 8 - Villa Hermosa', 'neighborhood': 'San Antonio', 'partition_date': '17062024', 'event_date': '17/06/2024 15:48:07', 'event_day': 17, 'event_hour': 15, 'event_minute': 48, 'event_month': 6, 'event_second': 7, 'event_year': 2024, 'current_temperature': 25.9}
# Enviado: {'latitude': 6.220574, 'longitude': -75.542085, 'date': '17/06/2024 15:48:08', 'customer_id': 1138, 'employee_id': 'Employee_119', 'quantity_products': 50, 'order_id': '45c4134a-50dd-46b6-9ab7-ddad125725b7', 'commune': 'Comuna 9 - Buenos Aires', 'neighborhood': 'Bomboná No. 2', 'partition_date': '17062024', 'event_date': '17/06/2024 15:48:08', 'event_day': 17, 'event_hour': 15, 'event_minute': 48, 'event_month': 6, 'event_second': 8, 'event_year': 2024, 'current_temperature': 25.9}
# Enviado: {'latitude': 6.23482, 'longitude': -75.54546, 'date': '17/06/2024 15:48:09', 'customer_id': 1418, 'employee_id': 'Employee_149', 'quantity_products': 50, 'order_id': '2deba84c-a2ee-46ec-906f-b9d869fe1e57', 'commune': 'Comuna 9 - Buenos Aires', 'neighborhood': 'Los Cerros - El Vergel', 'partition_date': '17062024', 'event_date': '17/06/2024 15:48:09', 'event_day': 17, 'event_hour': 15, 'event_minute': 48, 'event_month': 6, 'event_second': 9, 'event_year': 2024, 'current_temperature': 25.9}
# Enviado: {'latitude': 6.295457, 'longitude': -75.557531, 'date': '17/06/2024 15:48:10', 'customer_id': 1727, 'employee_id': 'Employee_127', 'quantity_products': 50, 'order_id': '35ff5f51-eeb0-4dc1-a574-154943d2371f', 'commune': 'Comuna 2 - Santa Cruz', 'neighborhood': 'Santa Cruz', 'partition_date': '17062024', 'event_date': '17/06/2024 15:48:10', 'event_day': 17, 'event_hour': 15, 'event_minute': 48, 'event_month': 6, 'event_second': 10, 'event_year': 2024, 'current_temperature': 25.9}
# Enviado: {'latitude': 6.304733, 'longitude': -75.563183, 'date': '17/06/2024 15:48:11', 'customer_id': 1661, 'employee_id': 'Employee_55', 'quantity_products': 50, 'order_id': 'c9664304-1fb0-447a-b4b9-9b2f75a02fa8', 'commune': 'Comuna 5 - Castilla', 'neighborhood': 'Boyacá', 'partition_date': '17062024', 'event_date': '17/06/2024 15:48:11', 'event_day': 17, 'event_hour': 15, 'event_minute': 48, 'event_month': 6, 'event_second': 11, 'event_year': 2024, 'current_temperature': 25.9}
# Enviado: {'latitude': 6.233554, 'longitude': -75.565071, 'date': '17/06/2024 15:48:12', 'customer_id': 1800, 'employee_id': 'Employee_129', 'quantity_products': 50, 'order_id': 'e006fb36-05ba-4949-a18d-6a7f54c48e72', 'commune': 'Comuna 10 - La Candelaria', 'neighborhood': 'Barrio San Diego', 'partition_date': '17062024', 'event_date': '17/06/2024 15:48:12', 'event_day': 17, 'event_hour': 15, 'event_minute': 48, 'event_month': 6, 'event_second': 12, 'event_year': 2024, 'current_temperature': 25.9}
# Enviado: {'latitude': 6.250895, 'longitude': -75.564412, 'date': '17/06/2024 15:48:13', 'customer_id': 1184, 'employee_id': 'Employee_193', 'quantity_products': 50, 'order_id': '692cfbf3-90c7-4a4b-ab52-701e553fa097', 'commune': 'Comuna 10 - La Candelaria', 'neighborhood': 'La Candelaria', 'partition_date': '17062024', 'event_date': '17/06/2024 15:48:13', 'event_day': 17, 'event_hour': 15, 'event_minute': 48, 'event_month': 6, 'event_second': 13, 'event_year': 2024, 'current_temperature': 25.9}
# Enviado: {'latitude': 6.217431, 'longitude': -75.528292, 'date': '17/06/2024 15:48:14', 'customer_id': 1404, 'employee_id': 'Employee_79', 'quantity_products': 50, 'order_id': '5d59748f-83f2-4e5b-bb2c-61d90fd88730', 'commune': 'Comuna 9 - Buenos Aires', 'neighborhood': 'Ocho de Marzo', 'partition_date': '17062024', 'event_date': '17/06/2024 15:48:14', 'event_day': 17, 'event_hour': 15, 'event_minute': 48, 'event_month': 6, 'event_second': 14, 'event_year': 2024, 'current_temperature': 25.9}
# Enviado: {'latitude': 6.256553, 'longitude': -75.552019, 'date': '17/06/2024 15:48:15', 'customer_id': 1774, 'employee_id': 'Employee_7', 'quantity_products': 50, 'order_id': 'ced55d4a-9b3f-4663-be70-405aa7825cd0', 'commune': 'Comuna 8 - Villa Hermosa', 'neighborhood': 'Villa Hermosa', 'partition_date': '17062024', 'event_date': '17/06/2024 15:48:15', 'event_day': 17, 'event_hour': 15, 'event_minute': 48, 'event_month': 6, 'event_second': 15, 'event_year': 2024, 'current_temperature': 25.9}
# Enviado: {'latitude': 6.268129, 'longitude': -75.532389, 'date': '17/06/2024 15:48:16', 'customer_id': 1294, 'employee_id': 'Employee_73', 'quantity_products': 50, 'order_id': '51b0a843-11a8-460b-a2e9-d9256a43d88f', 'commune': 'Comuna 3 - Manrique', 'neighborhood': 'La Cruz', 'partition_date': '17062024', 'event_date': '17/06/2024 15:48:16', 'event_day': 17, 'event_hour': 15, 'event_minute': 48, 'event_month': 6, 'event_second': 16, 'event_year': 2024, 'current_temperature': 25.9}
# Enviado: {'latitude': 6.227021, 'longitude': -75.554104, 'date': '17/06/2024 15:48:17', 'customer_id': 1315, 'employee_id': 'Employee_159', 'quantity_products': 50, 'order_id': '25c58acc-89b9-4440-b42f-ae8061f6501b', 'commune': 'Comuna 9 - Buenos Aires', 'neighborhood': 'La Asomadera No. 3', 'partition_date': '17062024', 'event_date': '17/06/2024 15:48:17', 'event_day': 17, 'event_hour': 15, 'event_minute': 48, 'event_month': 6, 'event_second': 17, 'event_year': 2024, 'current_temperature': 25.9}
# Enviado: {'latitude': 6.233771, 'longitude': -75.542107, 'date': '17/06/2024 15:48:18', 'customer_id': 1552, 'employee_id': 'Employee_51', 'quantity_products': 50, 'order_id': 'e1d93fba-203f-42b1-9e9f-3261af5a4323', 'commune': 'Comuna 9 - Buenos Aires', 'neighborhood': 'Los Cerros - El Vergel', 'partition_date': '17062024', 'event_date': '17/06/2024 15:48:18', 'event_day': 17, 'event_hour': 15, 'event_minute': 48, 'event_month': 6, 'event_second': 18, 'event_year': 2024, 'current_temperature': 25.9}
# Enviado: {'latitude': 6.301091, 'longitude': -75.548209, 'date': '17/06/2024 15:48:19', 'customer_id': 1212, 'employee_id': 'Employee_115', 'quantity_products': 50, 'order_id': 'd1510b0c-2aa8-4f43-9f38-3b5ff6259718', 'commune': 'Comuna 1 - Popular', 'neighborhood': 'Popular', 'partition_date': '17062024', 'event_date': '17/06/2024 15:48:19', 'event_day': 17, 'event_hour': 15, 'event_minute': 48, 'event_month': 6, 'event_second': 19, 'event_year': 2024, 'current_temperature': 25.9}
# Enviado: {'latitude': 6.263214, 'longitude': -75.565651, 'date': '17/06/2024 15:48:20', 'customer_id': 1379, 'employee_id': 'Employee_117', 'quantity_products': 41, 'order_id': '726cddbf-603e-41d7-8b38-aa15ac16e354', 'commune': 'Comuna 10 - La Candelaria', 'neighborhood': 'Prado', 'partition_date': '17062024', 'event_date': '17/06/2024 15:48:20', 'event_day': 17, 'event_hour': 15, 'event_minute': 48, 'event_month': 6, 'event_second': 20, 'event_year': 2024, 'current_temperature': 25.9}
# Enviado: {'latitude': 6.230866, 'longitude': -75.530405, 'date': '17/06/2024 15:48:21', 'customer_id': 1337, 'employee_id': 'Employee_81', 'quantity_products': 50, 'order_id': '608ba601-d424-46c0-8e60-656f8c7ee9a9', 'commune': 'Comuna 8 - Villa Hermosa', 'neighborhood': 'Las Estancias', 'partition_date': '17062024', 'event_date': '17/06/2024 15:48:21', 'event_day': 17, 'event_hour': 15, 'event_minute': 48, 'event_month': 6, 'event_second': 21, 'event_year': 2024, 'current_temperature': 25.9}
# Enviado: {'latitude': 6.243513, 'longitude': -75.541338, 'date': '17/06/2024 15:48:22', 'customer_id': 1410, 'employee_id': 'Employee_21', 'quantity_products': 50, 'order_id': 'df29b3f6-394f-406e-83d7-c7f3500aa09d', 'commune': 'Comuna 8 - Villa Hermosa', 'neighborhood': 'Trece de Noviembre', 'partition_date': '17062024', 'event_date': '17/06/2024 15:48:22', 'event_day': 17, 'event_hour': 15, 'event_minute': 48, 'event_month': 6, 'event_second': 22, 'event_year': 2024, 'current_temperature': 25.9}
# Enviado: {'latitude': 6.283403, 'longitude': -75.545891, 'date': '17/06/2024 15:48:23', 'customer_id': 1950, 'employee_id': 'Employee_197', 'quantity_products': 50, 'order_id': '2650891f-77a1-4aa0-bebb-c79309e30a21', 'commune': 'Comuna 3 - Manrique', 'neighborhood': 'La Salle', 'partition_date': '17062024', 'event_date': '17/06/2024 15:48:23', 'event_day': 17, 'event_hour': 15, 'event_minute': 48, 'event_month': 6, 'event_second': 23, 'event_year': 2024, 'current_temperature': 25.9}
# Enviado: {'latitude': 6.30835, 'longitude': -75.555155, 'date': '17/06/2024 15:48:24', 'customer_id': 1755, 'employee_id': 'Employee_15', 'quantity_products': 46, 'order_id': 'ed55b206-9795-4562-b1c5-f1d247f9b18d', 'commune': 'Comuna 2 - Santa Cruz', 'neighborhood': 'Playón de Los Comuneros', 'partition_date': '17062024', 'event_date': '17/06/2024 15:48:24', 'event_day': 17, 'event_hour': 15, 'event_minute': 48, 'event_month': 6, 'event_second': 24, 'event_year': 2024, 'current_temperature': 25.9}
# Enviado: {'latitude': 6.254946, 'longitude': -75.558221, 'date': '17/06/2024 15:48:25', 'customer_id': 1724, 'employee_id': 'Employee_147', 'quantity_products': 50, 'order_id': '1d03cc9c-2e9d-449a-941e-88ab77e5653d', 'commune': 'Comuna 8 - Villa Hermosa', 'neighborhood': 'San Miguel', 'partition_date': '17062024', 'event_date': '17/06/2024 15:48:25', 'event_day': 17, 'event_hour': 15, 'event_minute': 48, 'event_month': 6, 'event_second': 25, 'event_year': 2024, 'current_temperature': 25.9}
# Enviado: {'latitude': 6.296513, 'longitude': -75.565534, 'date': '17/06/2024 15:48:26', 'customer_id': 1020, 'employee_id': 'Employee_43', 'quantity_products': 50, 'order_id': '60fe8f34-a96d-46ee-9f85-3eb67b5446d5', 'commune': 'Comuna 5 - Castilla', 'neighborhood': 'Belalcázar', 'partition_date': '17062024', 'event_date': '17/06/2024 15:48:26', 'event_day': 17, 'event_hour': 15, 'event_minute': 48, 'event_month': 6, 'event_second': 26, 'event_year': 2024, 'current_temperature': 25.9}
# Enviado: {'latitude': 6.299954, 'longitude': -75.559406, 'date': '17/06/2024 15:48:28', 'customer_id': 1841, 'employee_id': 'Employee_141', 'quantity_products': 50, 'order_id': '500edbae-b0ba-4afd-a19b-8ca4c3a963d3', 'commune': 'Comuna 5 - Castilla', 'neighborhood': 'Héctor Abad Gómez', 'partition_date': '17062024', 'event_date': '17/06/2024 15:48:28', 'event_day': 17, 'event_hour': 15, 'event_minute': 48, 'event_month': 6, 'event_second': 28, 'event_year': 2024, 'current_temperature': 25.9}
# Enviado: {'latitude': 6.227021, 'longitude': -75.554104, 'date': '17/06/2024 15:48:29', 'customer_id': 1058, 'employee_id': 'Employee_159', 'quantity_products': 50, 'order_id': '977a1e2d-39f1-439d-a19c-0422d287b409', 'commune': 'Comuna 9 - Buenos Aires', 'neighborhood': 'La Asomadera No. 3', 'partition_date': '17062024', 'event_date': '17/06/2024 15:48:29', 'event_day': 17, 'event_hour': 15, 'event_minute': 48, 'event_month': 6, 'event_second': 29, 'event_year': 2024, 'current_temperature': 25.9}
# Enviado: {'latitude': 6.229471, 'longitude': -75.556631, 'date': '17/06/2024 15:48:30', 'customer_id': 1512, 'employee_id': 'Employee_113', 'quantity_products': 50, 'order_id': 'f2976ab5-e5cc-46b8-bfe7-8bedf7f14ccd', 'commune': 'Comuna 9 - Buenos Aires', 'neighborhood': 'Loreto', 'partition_date': '17062024', 'event_date': '17/06/2024 15:48:30', 'event_day': 17, 'event_hour': 15, 'event_minute': 48, 'event_month': 6, 'event_second': 30, 'event_year': 2024, 'current_temperature': 25.9}
# Enviado: {'latitude': 6.22135, 'longitude': -75.548236, 'date': '17/06/2024 15:48:31', 'customer_id': 1418, 'employee_id': 'Employee_101', 'quantity_products': 50, 'order_id': 'a43ea58e-9ea8-4cb4-8d06-62db6157eadf', 'commune': 'Comuna 9 - Buenos Aires', 'neighborhood': 'La Asomadera No. 3', 'partition_date': '17062024', 'event_date': '17/06/2024 15:48:31', 'event_day': 17, 'event_hour': 15, 'event_minute': 48, 'event_month': 6, 'event_second': 31, 'event_year': 2024, 'current_temperature': 25.9}
# Enviado: {'latitude': 6.254579, 'longitude': -75.538353, 'date': '17/06/2024 15:48:32', 'customer_id': 1844, 'employee_id': 'Employee_47', 'quantity_products': 50, 'order_id': '2babaa42-554c-4dab-b8e7-838247ec29af', 'commune': 'Comuna 8 - Villa Hermosa', 'neighborhood': 'Llanaditas', 'partition_date': '17062024', 'event_date': '17/06/2024 15:48:32', 'event_day': 17, 'event_hour': 15, 'event_minute': 48, 'event_month': 6, 'event_second': 32, 'event_year': 2024, 'current_temperature': 25.9}
# Enviado: {'latitude': 6.241087, 'longitude': -75.54213, 'date': '17/06/2024 15:48:33', 'customer_id': 1646, 'employee_id': 'Employee_37', 'quantity_products': 50, 'order_id': '4aa55838-ef9e-42b5-aa5d-605192ecc92a', 'commune': 'Comuna 8 - Villa Hermosa', 'neighborhood': 'La Libertad', 'partition_date': '17062024', 'event_date': '17/06/2024 15:48:33', 'event_day': 17, 'event_hour': 15, 'event_minute': 48, 'event_month': 6, 'event_second': 33, 'event_year': 2024, 'current_temperature': 25.9}
# Enviado: {'latitude': 6.229471, 'longitude': -75.556631, 'date': '17/06/2024 15:48:34', 'customer_id': 1404, 'employee_id': 'Employee_113', 'quantity_products': 50, 'order_id': '7eb231c8-4a23-40c3-bbba-e2f969ffeaf9', 'commune': 'Comuna 9 - Buenos Aires', 'neighborhood': 'Loreto', 'partition_date': '17062024', 'event_date': '17/06/2024 15:48:34', 'event_day': 17, 'event_hour': 15, 'event_minute': 48, 'event_month': 6, 'event_second': 34, 'event_year': 2024, 'current_temperature': 25.9}
# Enviado: {'latitude': 6.227021, 'longitude': -75.554104, 'date': '17/06/2024 15:48:35', 'customer_id': 1294, 'employee_id': 'Employee_159', 'quantity_products': 50, 'order_id': 'f7b8ddf6-4e92-4a20-8505-f4e63f5a0da0', 'commune': 'Comuna 9 - Buenos Aires', 'neighborhood': 'La Asomadera No. 3', 'partition_date': '17062024', 'event_date': '17/06/2024 15:48:35', 'event_day': 17, 'event_hour': 15, 'event_minute': 48, 'event_month': 6, 'event_second': 35, 'event_year': 2024, 'current_temperature': 25.9}
# ...
# Enviado: {'latitude': 6.233505, 'longitude': -75.539321, 'date': '17/06/2024 17:30:22', 'customer_id': 1858, 'employee_id': 'Employee_103', 'quantity_products': 38, 'order_id': '14f959a1-2c66-4fb1-a94a-219c567c93d6', 'commune': 'Comuna 8 - Villa Hermosa', 'neighborhood': 'Villa Tina', 'partition_date': '17062024', 'event_date': '17/06/2024 17:30:22', 'event_day': 17, 'event_hour': 17, 'event_minute': 30, 'event_month': 6, 'event_second': 22, 'event_year': 2024, 'current_temperature': 22.9}
# Enviado: {'latitude': 6.302827, 'longitude': -75.560455, 'date': '17/06/2024 17:30:23', 'customer_id': 1971, 'employee_id': 'Employee_63', 'quantity_products': 44, 'order_id': '83b1119b-4f17-4275-9a1a-6f152379cef9', 'commune': 'Comuna 5 - Castilla', 'neighborhood': 'Héctor Abad Gómez', 'partition_date': '17062024', 'event_date': '17/06/2024 17:30:23', 'event_day': 17, 'event_hour': 17, 'event_minute': 30, 'event_month': 6, 'event_second': 23, 'event_year': 2024, 'current_temperature': 22.9}
# Enviado: {'latitude': 6.231786, 'longitude': -75.538967, 'date': '17/06/2024 17:30:24', 'customer_id': 1392, 'employee_id': 'Employee_173', 'quantity_products': 49, 'order_id': '5adc9435-e816-4b21-b711-8ee27a097a2b', 'commune': 'Comuna 9 - Buenos Aires', 'neighborhood': 'Barrios de Jesús', 'partition_date': '17062024', 'event_date': '17/06/2024 17:30:24', 'event_day': 17, 'event_hour': 17, 'event_minute': 30, 'event_month': 6, 'event_second': 24, 'event_year': 2024, 'current_temperature': 22.9}
# Enviado: {'latitude': 6.283403, 'longitude': -75.545891, 'date': '17/06/2024 17:30:25', 'customer_id': 1230, 'employee_id': 'Employee_197', 'quantity_products': 23, 'order_id': '7a16ce6c-f431-477a-ba80-da733acc7afa', 'commune': 'Comuna 3 - Manrique', 'neighborhood': 'La Salle', 'partition_date': '17062024', 'event_date': '17/06/2024 17:30:25', 'event_day': 17, 'event_hour': 17, 'event_minute': 30, 'event_month': 6, 'event_second': 25, 'event_year': 2024, 'current_temperature': 22.9}
# Enviado: {'latitude': 6.300545, 'longitude': -75.563593, 'date': '17/06/2024 17:30:26', 'customer_id': 1848, 'employee_id': 'Employee_179', 'quantity_products': 38, 'order_id': '451a60b8-12c8-468b-aa19-f5ab2cd629ff', 'commune': 'Comuna 5 - Castilla', 'neighborhood': 'Boyacá', 'partition_date': '17062024', 'event_date': '17/06/2024 17:30:26', 'event_day': 17, 'event_hour': 17, 'event_minute': 30, 'event_month': 6, 'event_second': 26, 'event_year': 2024, 'current_temperature': 22.9}
# Enviado: {'latitude': 6.230866, 'longitude': -75.530405, 'date': '17/06/2024 17:30:27', 'customer_id': 1655, 'employee_id': 'Employee_81', 'quantity_products': 49, 'order_id': 'f17202e1-e229-4fb4-82d9-83762082bc88', 'commune': 'Comuna 8 - Villa Hermosa', 'neighborhood': 'Las Estancias', 'partition_date': '17062024', 'event_date': '17/06/2024 17:30:27', 'event_day': 17, 'event_hour': 17, 'event_minute': 30, 'event_month': 6, 'event_second': 27, 'event_year': 2024, 'current_temperature': 22.9}
# Enviado: {'latitude': 6.228642, 'longitude': -75.529782, 'date': '17/06/2024 17:30:28', 'customer_id': 1344, 'employee_id': 'Employee_31', 'quantity_products': 31, 'order_id': 'b87960fc-93a6-41e3-a596-dc065e2f7103', 'commune': 'Comuna 9 - Buenos Aires', 'neighborhood': 'Ocho de Marzo', 'partition_date': '17062024', 'event_date': '17/06/2024 17:30:28', 'event_day': 17, 'event_hour': 17, 'event_minute': 30, 'event_month': 6, 'event_second': 28, 'event_year': 2024, 'current_temperature': 22.9}
# Enviado: {'latitude': 6.240547, 'longitude': -75.537934, 'date': '17/06/2024 17:30:29', 'customer_id': 1130, 'employee_id': 'Employee_75', 'quantity_products': 50, 'order_id': '7c252269-c408-4bd9-94ad-447fabc84a62', 'commune': 'Comuna 8 - Villa Hermosa', 'neighborhood': 'Villa Tina', 'partition_date': '17062024', 'event_date': '17/06/2024 17:30:29', 'event_day': 17, 'event_hour': 17, 'event_minute': 30, 'event_month': 6, 'event_second': 29, 'event_year': 2024, 'current_temperature': 22.9}
# Enviado: {'latitude': 6.229935, 'longitude': -75.556966, 'date': '17/06/2024 17:30:30', 'customer_id': 1296, 'employee_id': 'Employee_165', 'quantity_products': 50, 'order_id': '9133609d-15e1-4809-9e03-a4568000cbb4', 'commune': 'Comuna 9 - Buenos Aires', 'neighborhood': 'Loreto', 'partition_date': '17062024', 'event_date': '17/06/2024 17:30:30', 'event_day': 17, 'event_hour': 17, 'event_minute': 30, 'event_month': 6, 'event_second': 30, 'event_year': 2024, 'current_temperature': 22.9}
# Enviado: {'latitude': 6.230978, 'longitude': -75.533582, 'date': '17/06/2024 17:30:31', 'customer_id': 1422, 'employee_id': 'Employee_9', 'quantity_products': 46, 'order_id': '933b3882-76f9-4eab-9b65-6987fc3c1259', 'commune': 'Comuna 9 - Buenos Aires', 'neighborhood': 'Barrios de Jesús', 'partition_date': '17062024', 'event_date': '17/06/2024 17:30:31', 'event_day': 17, 'event_hour': 17, 'event_minute': 30, 'event_month': 6, 'event_second': 31, 'event_year': 2024, 'current_temperature': 22.9}
# Enviado: {'latitude': 6.231971, 'longitude': -75.54485, 'date': '17/06/2024 17:30:32', 'customer_id': 1632, 'employee_id': 'Employee_189', 'quantity_products': 50, 'order_id': '86c78cf4-e20d-4804-9073-3373234b5416', 'commune': 'Comuna 9 - Buenos Aires', 'neighborhood': 'Bomboná No. 2', 'partition_date': '17062024', 'event_date': '17/06/2024 17:30:32', 'event_day': 17, 'event_hour': 17, 'event_minute': 30, 'event_month': 6, 'event_second': 32, 'event_year': 2024, 'current_temperature': 22.9}
# Enviado: {'latitude': 6.233249, 'longitude': -75.544511, 'date': '17/06/2024 17:30:33', 'customer_id': 1229, 'employee_id': 'Employee_153', 'quantity_products': 41, 'order_id': 'd8f2f698-76c6-4a68-8ded-728a92d67335', 'commune': 'Comuna 9 - Buenos Aires', 'neighborhood': 'Los Cerros - El Vergel', 'partition_date': '17062024', 'event_date': '17/06/2024 17:30:33', 'event_day': 17, 'event_hour': 17, 'event_minute': 30, 'event_month': 6, 'event_second': 33, 'event_year': 2024, 'current_temperature': 22.9}
# Enviado: {'latitude': 6.22135, 'longitude': -75.548236, 'date': '17/06/2024 17:30:34', 'customer_id': 1275, 'employee_id': 'Employee_101', 'quantity_products': 43, 'order_id': '1fa17cd4-6bef-46d2-acc4-ba210206fa31', 'commune': 'Comuna 9 - Buenos Aires', 'neighborhood': 'La Asomadera No. 3', 'partition_date': '17062024', 'event_date': '17/06/2024 17:30:34', 'event_day': 17, 'event_hour': 17, 'event_minute': 30, 'event_month': 6, 'event_second': 34, 'event_year': 2024, 'current_temperature': 22.9}
# Enviado: {'latitude': 6.228642, 'longitude': -75.529782, 'date': '17/06/2024 17:30:35', 'customer_id': 1470, 'employee_id': 'Employee_31', 'quantity_products': 50, 'order_id': '1a2da4e2-8be8-41d6-9962-e5714f3fa582', 'commune': 'Comuna 9 - Buenos Aires', 'neighborhood': 'Ocho de Marzo', 'partition_date': '17062024', 'event_date': '17/06/2024 17:30:35', 'event_day': 17, 'event_hour': 17, 'event_minute': 30, 'event_month': 6, 'event_second': 35, 'event_year': 2024, 'current_temperature': 22.9}
# Enviado: {'latitude': 6.2684, 'longitude': -75.552571, 'date': '17/06/2024 17:30:37', 'customer_id': 1199, 'employee_id': 'Employee_137', 'quantity_products': 47, 'order_id': 'ab4522c7-2a38-45cc-8f11-00e3d86e95ee', 'commune': 'Comuna 3 - Manrique', 'neighborhood': 'El Pomar', 'partition_date': '17062024', 'event_date': '17/06/2024 17:30:37', 'event_day': 17, 'event_hour': 17, 'event_minute': 30, 'event_month': 6, 'event_second': 37, 'event_year': 2024, 'current_temperature': 22.9}
# Enviado: {'latitude': 6.233505, 'longitude': -75.539321, 'date': '17/06/2024 17:30:38', 'customer_id': 1406, 'employee_id': 'Employee_103', 'quantity_products': 38, 'order_id': 'ca83bca1-5168-4189-86f8-1c7c3137f9a5', 'commune': 'Comuna 8 - Villa Hermosa', 'neighborhood': 'Villa Tina', 'partition_date': '17062024', 'event_date': '17/06/2024 17:30:38', 'event_day': 17, 'event_hour': 17, 'event_minute': 30, 'event_month': 6, 'event_second': 38, 'event_year': 2024, 'current_temperature': 22.9}
# Enviado: {'latitude': 6.218558, 'longitude': -75.560038, 'date': '17/06/2024 17:30:39', 'customer_id': 1438, 'employee_id': 'Employee_187', 'quantity_products': 33, 'order_id': '4487e40f-d6d2-439a-b8d2-321954917445', 'commune': 'Comuna 9 - Buenos Aires', 'neighborhood': 'La Asomadera No. 3', 'partition_date': '17062024', 'event_date': '17/06/2024 17:30:39', 'event_day': 17, 'event_hour': 17, 'event_minute': 30, 'event_month': 6, 'event_second': 39, 'event_year': 2024, 'current_temperature': 22.9}
# Enviado: {'latitude': 6.241721, 'longitude': -75.544554, 'date': '17/06/2024 17:30:40', 'customer_id': 1475, 'employee_id': 'Employee_83', 'quantity_products': 50, 'order_id': '16aa1d1f-dd9f-4f2a-921d-015e6b56b333', 'commune': 'Comuna 8 - Villa Hermosa', 'neighborhood': 'La Libertad', 'partition_date': '17062024', 'event_date': '17/06/2024 17:30:40', 'event_day': 17, 'event_hour': 17, 'event_minute': 30, 'event_month': 6, 'event_second': 40, 'event_year': 2024, 'current_temperature': 22.9}
# Enviado: {'latitude': 6.269597, 'longitude': -75.531581, 'date': '17/06/2024 17:30:41', 'customer_id': 1608, 'employee_id': 'Employee_17', 'quantity_products': 34, 'order_id': '4c1d37b5-bad1-4ec5-8665-7aa97a941040', 'commune': 'Comuna 3 - Manrique', 'neighborhood': 'La Cruz', 'partition_date': '17062024', 'event_date': '17/06/2024 17:30:41', 'event_day': 17, 'event_hour': 17, 'event_minute': 30, 'event_month': 6, 'event_second': 41, 'event_year': 2024, 'current_temperature': 22.9}
# Enviado: {'latitude': 6.298354, 'longitude': -75.564556, 'date': '17/06/2024 17:30:42', 'customer_id': 1024, 'employee_id': 'Employee_71', 'quantity_products': 29, 'order_id': 'e79ca22a-b435-41a1-b0a4-2bf9830e06e7', 'commune': 'Comuna 5 - Castilla', 'neighborhood': 'Villa Niza', 'partition_date': '17062024', 'event_date': '17/06/2024 17:30:42', 'event_day': 17, 'event_hour': 17, 'event_minute': 30, 'event_month': 6, 'event_second': 42, 'event_year': 2024, 'current_temperature': 22.9}
# Enviado: {'latitude': 6.300545, 'longitude': -75.563593, 'date': '17/06/2024 17:30:43', 'customer_id': 1462, 'employee_id': 'Employee_179', 'quantity_products': 34, 'order_id': '59338fd5-523f-45ee-9b06-5705e648bd0e', 'commune': 'Comuna 5 - Castilla', 'neighborhood': 'Boyacá', 'partition_date': '17062024', 'event_date': '17/06/2024 17:30:43', 'event_day': 17, 'event_hour': 17, 'event_minute': 30, 'event_month': 6, 'event_second': 43, 'event_year': 2024, 'current_temperature': 22.9}
# Enviado: {'latitude': 6.240851, 'longitude': -75.564423, 'date': '17/06/2024 17:30:44', 'customer_id': 1832, 'employee_id': 'Employee_91', 'quantity_products': 50, 'order_id': '524c645c-4647-45d5-8be3-1af05e330904', 'commune': 'Comuna 10 - La Candelaria', 'neighborhood': 'Bomboná No. 1', 'partition_date': '17062024', 'event_date': '17/06/2024 17:30:44', 'event_day': 17, 'event_hour': 17, 'event_minute': 30, 'event_month': 6, 'event_second': 44, 'event_year': 2024, 'current_temperature': 22.9}
# Enviado: {'latitude': 6.31383, 'longitude': -75.556608, 'date': '17/06/2024 17:30:45', 'customer_id': 1831, 'employee_id': 'Employee_45', 'quantity_products': 23, 'order_id': '5dd7f29a-3a89-48cd-af25-b1655e8a03ed', 'commune': 'Comuna 5 - Castilla', 'neighborhood': 'La Florida', 'partition_date': '17062024', 'event_date': '17/06/2024 17:30:45', 'event_day': 17, 'event_hour': 17, 'event_minute': 30, 'event_month': 6, 'event_second': 45, 'event_year': 2024, 'current_temperature': 22.9}
# Enviado: {'latitude': 6.233249, 'longitude': -75.544511, 'date': '17/06/2024 17:30:46', 'customer_id': 1107, 'employee_id': 'Employee_153', 'quantity_products': 48, 'order_id': '4392faf6-47ef-4ffb-997f-679de35fe875', 'commune': 'Comuna 9 - Buenos Aires', 'neighborhood': 'Los Cerros - El Vergel', 'partition_date': '17062024', 'event_date': '17/06/2024 17:30:46', 'event_day': 17, 'event_hour': 17, 'event_minute': 30, 'event_month': 6, 'event_second': 46, 'event_year': 2024, 'current_temperature': 22.9}
# Enviado: {'latitude': 6.239573, 'longitude': -75.549006, 'date': '17/06/2024 17:30:47', 'customer_id': 1499, 'employee_id': 'Employee_57', 'quantity_products': 35, 'order_id': '7b3260f4-4c73-416e-9f16-bb137e01f163', 'commune': 'Comuna 9 - Buenos Aires', 'neighborhood': 'Miraflores', 'partition_date': '17062024', 'event_date': '17/06/2024 17:30:47', 'event_day': 17, 'event_hour': 17, 'event_minute': 30, 'event_month': 6, 'event_second': 47, 'event_year': 2024, 'current_temperature': 22.9}
# Enviado: {'latitude': 6.299954, 'longitude': -75.559406, 'date': '17/06/2024 17:30:48', 'customer_id': 1441, 'employee_id': 'Employee_141', 'quantity_products': 35, 'order_id': '4cc531f4-716d-4d37-a413-3aa253fa757d', 'commune': 'Comuna 5 - Castilla', 'neighborhood': 'Héctor Abad Gómez', 'partition_date': '17062024', 'event_date': '17/06/2024 17:30:48', 'event_day': 17, 'event_hour': 17, 'event_minute': 30, 'event_month': 6, 'event_second': 48, 'event_year': 2024, 'current_temperature': 22.9}
# Enviado: {'latitude': 6.218558, 'longitude': -75.560038, 'date': '17/06/2024 17:30:49', 'customer_id': 1142, 'employee_id': 'Employee_187', 'quantity_products': 30, 'order_id': 'fd594b7f-c19c-4524-90d3-0465633abe75', 'commune': 'Comuna 9 - Buenos Aires', 'neighborhood': 'La Asomadera No. 3', 'partition_date': '17062024', 'event_date': '17/06/2024 17:30:49', 'event_day': 17, 'event_hour': 17, 'event_minute': 30, 'event_month': 6, 'event_second': 49, 'event_year': 2024, 'current_temperature': 22.9}
# Enviado: {'latitude': 6.243513, 'longitude': -75.541338, 'date': '17/06/2024 17:30:50', 'customer_id': 1076, 'employee_id': 'Employee_21', 'quantity_products': 50, 'order_id': '0908f0dc-d980-462b-afc8-ee84920ffe92', 'commune': 'Comuna 8 - Villa Hermosa', 'neighborhood': 'Trece de Noviembre', 'partition_date': '17062024', 'event_date': '17/06/2024 17:30:50', 'event_day': 17, 'event_hour': 17, 'event_minute': 30, 'event_month': 6, 'event_second': 50, 'event_year': 2024, 'current_temperature': 22.9}
# Enviado: {'latitude': 6.229935, 'longitude': -75.556966, 'date': '17/06/2024 17:30:51', 'customer_id': 1373, 'employee_id': 'Employee_165', 'quantity_products': 42, 'order_id': '876812f5-a2ac-440e-a371-79e9f7bb9fcf', 'commune': 'Comuna 9 - Buenos Aires', 'neighborhood': 'Loreto', 'partition_date': '17062024', 'event_date': '17/06/2024 17:30:51', 'event_day': 17, 'event_hour': 17, 'event_minute': 30, 'event_month': 6, 'event_second': 51, 'event_year': 2024, 'current_temperature': 22.9}
# Enviado: {'latitude': 6.255342, 'longitude': -75.555875, 'date': '17/06/2024 17:30:52', 'customer_id': 1366, 'employee_id': 'Employee_157', 'quantity_products': 30, 'order_id': '8e529e9b-b9d0-4bef-8758-de4ff75f1abf', 'commune': 'Comuna 8 - Villa Hermosa', 'neighborhood': 'San Miguel', 'partition_date': '17062024', 'event_date': '17/06/2024 17:30:52', 'event_day': 17, 'event_hour': 17, 'event_minute': 30, 'event_month': 6, 'event_second': 52, 'event_year': 2024, 'current_temperature': 22.9}
# Enviado: {'latitude': 6.239573, 'longitude': -75.549006, 'date': '17/06/2024 17:30:53', 'customer_id': 1230, 'employee_id': 'Employee_57', 'quantity_products': 43, 'order_id': '164a9ad3-9c64-4e07-b1cf-c0d50338af91', 'commune': 'Comuna 9 - Buenos Aires', 'neighborhood': 'Miraflores', 'partition_date': '17062024', 'event_date': '17/06/2024 17:30:53', 'event_day': 17, 'event_hour': 17, 'event_minute': 30, 'event_month': 6, 'event_second': 53, 'event_year': 2024, 'current_temperature': 22.9}
# Enviado: {'latitude': 6.232999, 'longitude': -75.53153, 'date': '17/06/2024 17:30:54', 'customer_id': 1625, 'employee_id': 'Employee_99', 'quantity_products': 30, 'order_id': '2dd9ab2d-de70-44f0-9597-52626cf9e727', 'commune': 'Comuna 8 - Villa Hermosa', 'neighborhood': 'Las Estancias', 'partition_date': '17062024', 'event_date': '17/06/2024 17:30:54', 'event_day': 17, 'event_hour': 17, 'event_minute': 30, 'event_month': 6, 'event_second': 54, 'event_year': 2024, 'current_temperature': 22.9}
