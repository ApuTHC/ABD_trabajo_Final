# %% [markdown]
# # Librerías

# %%
# pip install geopy

# %%
# pip install meteostat

# %%
import json
import time
import uuid
import random
from datetime import datetime, timedelta
import pytz
from geopy.geocoders import Nominatim
from meteostat import Point, Hourly

# %% [markdown]
# # Geolocalizador

# %%
# Definir las coordenadas aproximadas de Medellín
lat_range = (6.217, 6.317)  # Latitud de Medellín
lon_range = (-75.567, -75.467)  # Longitud de Medellín

# Inicializar el geolocalizador
geolocator = Nominatim(user_agent="medellin_locator")

# %% [markdown]
# # Obtención de datos

# %%
# Función para obtener la comuna y barrio según las coordenadas
def get_location_info(latitude, longitude):
    location = geolocator.reverse((latitude, longitude), language='es')
    address = location.raw['address']
    comuna = address.get('suburb', 'No encontrado')
    barrio = address.get('neighbourhood', 'No encontrado')
    return comuna, barrio

# Generar puntos de venta únicos
def generate_valid_points(n):
    valid_points = []
    while len(valid_points) < n:
        lat = round(random.uniform(*lat_range), 6)
        lon = round(random.uniform(*lon_range), 6)
        comuna, barrio = get_location_info(lat, lon)
        if comuna != 'No encontrado' and barrio != 'No encontrado':
            valid_points.append((lat, lon, comuna, barrio))
    return valid_points

# Generar 100 puntos válidos
points_of_sale = generate_valid_points(100)

# Generar 200 empleados, 2 por cada punto de venta
employees = {i: (f"Employee_{i*2+1}", f"Employee_{i*2+2}") for i in range(100)}

# Función para obtener la temperatura actual
# def get_current_temperature(latitude, longitude):
#     location = Point(latitude, longitude)
#     start = datetime.now() - timedelta(hours=1)
#     end = datetime.now()
#     data = Hourly(location, start, end)
#     data = data.fetch()
#     temperature = data['temp'].mean() if not data.empty else 'No data'
#     return round(temperature, 1)

# Generar datos simulados
def generate_event(pos_index):
    pos = points_of_sale[pos_index]
    worker = employees[pos_index]
    date_now = datetime.now(pytz.timezone('America/Bogota'))
    # temperature = get_current_temperature(pos[0], pos[1])
    
    event = {
        "latitude": pos[0],
        "longitude": pos[1],
        "date": date_now.strftime("%d/%m/%Y %H:%M:%S"),
        "customer_id": random.randint(1000, 2000),
        "employee_id": worker[0] if date_now.weekday() < 5 else worker[1],  # Lunes a Viernes / Fines de Semana
        "quantity_products": random.randint(1, 50),
        "order_id": str(uuid.uuid4())
    }
    
    # "commune": pos[2],
    # "neighborhood": pos[3],
    # "partition_date": date_now.strftime("%d%m%Y"),
    # "event_date": date_now.strftime("%d/%m/%Y %H:%M:%S"),
    # "event_day": date_now.day,
    # "event_hour": date_now.hour,
    # "event_minute": date_now.minute,
    # "event_month": date_now.month,
    # "event_second": date_now.second,
    # "event_year": date_now.year
    # "current_temperature": temperature
    
    return event

# Enviar los datos
def send_data(s, conn, data):
    conn.sendall(json.dumps(data).encode() + b'\n')
    print("enviado:", data)

# %% [markdown]
# # Socket

# %%
import socket

# %%
# Socket
def servidor():
    
    host = 'localhost'  # Nombre del host o dirección IP
    port = 5555  # Puerto en el que escucha el servidor

    s = socket.socket()
    s.bind((host, port))
    s.listen(1)
    print(f"Listening on {host}:{port}")
    
    conn, addr = s.accept()
    print(f"Connection from {addr}")
    
    try:
        while True:
            event = generate_event(random.randint(0, 99))
            # Esperar 30 segundos antes de generar el siguiente evento
            send_data(s, conn, event)
            # Guardado en un archivo JSON
            with open('simulated_data.json', 'a') as file:
                file.write(json.dumps(event) + "\n")
            
            time.sleep(1)
            
    except KeyboardInterrupt:
        print("Deteniendo el servidor...")
        conn.close()
        s.close()
        print("Conexión cerrada.")
    
    except BrokenPipeError:
        print("La conexión ha sido cerrada.")
        conn.close()
        s.close()

if __name__ == "__main__":
    servidor()
# Out:
# Listening on localhost:5555
# Connection from ('127.0.0.1', 36260)
# enviado: {'latitude': 6.251592, 'longitude': -75.561356, 'date': '15/06/2024 01:40:14', 'customer_id': 1122, 'employee_id': 'Employee_86', 'quantity_products': 3, 'order_id': '7467388f-362e-4610-91c3-ac837ceb5a1a'}
# enviado: {'latitude': 6.272041, 'longitude': -75.558372, 'date': '15/06/2024 01:40:15', 'customer_id': 1668, 'employee_id': 'Employee_62', 'quantity_products': 49, 'order_id': '6378ed48-8c02-4fe3-a868-ca9b4493eaf0'}
# enviado: {'latitude': 6.229974, 'longitude': -75.564394, 'date': '15/06/2024 01:40:16', 'customer_id': 1407, 'employee_id': 'Employee_142', 'quantity_products': 18, 'order_id': '062c639a-b6a9-4e81-9668-44fdcf5eed50'}
# enviado: {'latitude': 6.302234, 'longitude': -75.549658, 'date': '15/06/2024 01:40:17', 'customer_id': 1351, 'employee_id': 'Employee_30', 'quantity_products': 48, 'order_id': '0bb93a18-9467-45ef-8fe9-7ef85e8962a9'}
# enviado: {'latitude': 6.223182, 'longitude': -75.553677, 'date': '15/06/2024 01:40:18', 'customer_id': 1681, 'employee_id': 'Employee_14', 'quantity_products': 21, 'order_id': '64446b59-1028-4883-8996-a26bba386c0d'}
# enviado: {'latitude': 6.223047, 'longitude': -75.551179, 'date': '15/06/2024 01:40:19', 'customer_id': 1905, 'employee_id': 'Employee_126', 'quantity_products': 30, 'order_id': 'a97c0986-2398-4e08-b57b-2d318d76e403'}
# enviado: {'latitude': 6.23152, 'longitude': -75.560023, 'date': '15/06/2024 01:40:20', 'customer_id': 1374, 'employee_id': 'Employee_130', 'quantity_products': 9, 'order_id': '9821d09c-5704-405b-9403-2ebd39df06b4'}
# enviado: {'latitude': 6.271346, 'longitude': -75.537942, 'date': '15/06/2024 01:40:21', 'customer_id': 1367, 'employee_id': 'Employee_58', 'quantity_products': 19, 'order_id': 'db441d01-13a6-4a9b-b128-f179cf2c936b'}
# enviado: {'latitude': 6.235559, 'longitude': -75.550291, 'date': '15/06/2024 01:40:22', 'customer_id': 1501, 'employee_id': 'Employee_36', 'quantity_products': 18, 'order_id': '23e2f680-fdda-47e3-89f3-4dd4ed22431d'}
# enviado: {'latitude': 6.297342, 'longitude': -75.540989, 'date': '15/06/2024 01:40:23', 'customer_id': 1300, 'employee_id': 'Employee_10', 'quantity_products': 44, 'order_id': '6eba6a6e-dc64-4ff0-8292-b155c7b89a17'}
# enviado: {'latitude': 6.246786, 'longitude': -75.56206, 'date': '15/06/2024 01:40:24', 'customer_id': 1286, 'employee_id': 'Employee_42', 'quantity_products': 22, 'order_id': '9c02c557-5339-4f46-acdd-addc12cbabf2'}
# enviado: {'latitude': 6.280355, 'longitude': -75.552415, 'date': '15/06/2024 01:40:25', 'customer_id': 1970, 'employee_id': 'Employee_164', 'quantity_products': 34, 'order_id': 'd9304d2a-c4a9-4c2b-96e0-5645626c404a'}
# enviado: {'latitude': 6.243884, 'longitude': -75.560869, 'date': '15/06/2024 01:40:26', 'customer_id': 1832, 'employee_id': 'Employee_72', 'quantity_products': 14, 'order_id': '941f8f54-6234-4a63-9cba-4dc1915bc18d'}
# enviado: {'latitude': 6.275377, 'longitude': -75.537934, 'date': '15/06/2024 01:40:27', 'customer_id': 1857, 'employee_id': 'Employee_144', 'quantity_products': 33, 'order_id': '1dccd99d-a197-4685-b918-8c998249f8e3'}
# enviado: {'latitude': 6.303074, 'longitude': -75.55662, 'date': '15/06/2024 01:40:28', 'customer_id': 1522, 'employee_id': 'Employee_94', 'quantity_products': 16, 'order_id': 'ead386df-943a-4240-832b-a09f44eaf206'}
# enviado: {'latitude': 6.229182, 'longitude': -75.545317, 'date': '15/06/2024 01:40:29', 'customer_id': 1904, 'employee_id': 'Employee_160', 'quantity_products': 36, 'order_id': '2af51b4b-5508-4ad4-a157-6c9677755e23'}
# enviado: {'latitude': 6.25177, 'longitude': -75.55035, 'date': '15/06/2024 01:40:30', 'customer_id': 1306, 'employee_id': 'Employee_182', 'quantity_products': 20, 'order_id': '13d811e8-4ca0-4a42-b86d-816b5249fbb5'}
# enviado: {'latitude': 6.220079, 'longitude': -75.533996, 'date': '15/06/2024 01:40:31', 'customer_id': 1091, 'employee_id': 'Employee_70', 'quantity_products': 29, 'order_id': '24d6803d-16d1-4f99-acbb-4211dc6e4bda'}
# enviado: {'latitude': 6.222297, 'longitude': -75.564221, 'date': '15/06/2024 01:40:32', 'customer_id': 1340, 'employee_id': 'Employee_192', 'quantity_products': 14, 'order_id': '2b35474a-90ef-45cf-b90c-582f4dbecc47'}
# enviado: {'latitude': 6.222883, 'longitude': -75.55123, 'date': '15/06/2024 01:40:33', 'customer_id': 1336, 'employee_id': 'Employee_68', 'quantity_products': 3, 'order_id': '0530a64a-8e5e-4313-bc07-9c45e8b4fe09'}
# enviado: {'latitude': 6.230483, 'longitude': -75.530208, 'date': '15/06/2024 01:40:34', 'customer_id': 1681, 'employee_id': 'Employee_198', 'quantity_products': 42, 'order_id': 'f6fc520b-7b74-4681-aac5-d84a18ceb1ff'}
# enviado: {'latitude': 6.237639, 'longitude': -75.565519, 'date': '15/06/2024 01:40:35', 'customer_id': 1860, 'employee_id': 'Employee_146', 'quantity_products': 26, 'order_id': 'c134990f-6077-4062-930e-de5357a90fb8'}
# enviado: {'latitude': 6.247898, 'longitude': -75.561711, 'date': '15/06/2024 01:40:36', 'customer_id': 1134, 'employee_id': 'Employee_136', 'quantity_products': 9, 'order_id': '80602adf-d146-4ecd-883c-b7f843bc62be'}
# enviado: {'latitude': 6.302234, 'longitude': -75.549658, 'date': '15/06/2024 01:40:37', 'customer_id': 1203, 'employee_id': 'Employee_30', 'quantity_products': 41, 'order_id': '834f297f-facd-4fc5-bec7-f3aeca0e9c37'}
# enviado: {'latitude': 6.290081, 'longitude': -75.554476, 'date': '15/06/2024 01:40:38', 'customer_id': 1724, 'employee_id': 'Employee_4', 'quantity_products': 40, 'order_id': '81009c9b-0d88-413c-99b7-1846f26fbf36'}
# enviado: {'latitude': 6.297342, 'longitude': -75.540989, 'date': '15/06/2024 01:40:39', 'customer_id': 1391, 'employee_id': 'Employee_10', 'quantity_products': 35, 'order_id': '172fb935-be60-4bc2-9604-c98cc436525d'}
# enviado: {'latitude': 6.230513, 'longitude': -75.566217, 'date': '15/06/2024 01:40:40', 'customer_id': 1266, 'employee_id': 'Employee_174', 'quantity_products': 43, 'order_id': '42ee0b08-c924-4fea-be4d-f364b1620373'}
# enviado: {'latitude': 6.257533, 'longitude': -75.566252, 'date': '15/06/2024 01:40:41', 'customer_id': 1957, 'employee_id': 'Employee_40', 'quantity_products': 2, 'order_id': '2351c05b-2ff8-4e9c-a10b-87db20152bc9'}
# enviado: {'latitude': 6.292262, 'longitude': -75.54032, 'date': '15/06/2024 01:40:42', 'customer_id': 1495, 'employee_id': 'Employee_110', 'quantity_products': 48, 'order_id': 'e81dae73-6234-4a78-829e-a328679b0ccf'}
# enviado: {'latitude': 6.231145, 'longitude': -75.549267, 'date': '15/06/2024 01:40:43', 'customer_id': 1280, 'employee_id': 'Employee_196', 'quantity_products': 33, 'order_id': '4d4d2808-094c-4cde-afc4-c1451d86a428'}
# enviado: {'latitude': 6.246891, 'longitude': -75.553032, 'date': '15/06/2024 01:40:44', 'customer_id': 1937, 'employee_id': 'Employee_100', 'quantity_products': 11, 'order_id': '7f485e79-eff6-4809-ba78-40bc0760829d'}
# enviado: {'latitude': 6.266529, 'longitude': -75.556324, 'date': '15/06/2024 01:40:45', 'customer_id': 1340, 'employee_id': 'Employee_34', 'quantity_products': 34, 'order_id': '52839c22-a973-48a8-84d5-e1de7e7c0107'}
# enviado: {'latitude': 6.241031, 'longitude': -75.555596, 'date': '15/06/2024 01:40:46', 'customer_id': 1850, 'employee_id': 'Employee_12', 'quantity_products': 8, 'order_id': 'e8ec4d89-dcbb-4d38-8636-16930d8be4c0'}
# enviado: {'latitude': 6.271624, 'longitude': -75.531737, 'date': '15/06/2024 01:40:47', 'customer_id': 1042, 'employee_id': 'Employee_194', 'quantity_products': 36, 'order_id': '18d32fe6-c784-4e8e-981d-e9118d0b9318'}
# enviado: {'latitude': 6.246786, 'longitude': -75.56206, 'date': '15/06/2024 01:40:48', 'customer_id': 1960, 'employee_id': 'Employee_42', 'quantity_products': 44, 'order_id': '7e46c010-b2b5-4eaf-8e27-93a6e255c5bf'}
# enviado: {'latitude': 6.25177, 'longitude': -75.55035, 'date': '15/06/2024 01:40:49', 'customer_id': 1531, 'employee_id': 'Employee_182', 'quantity_products': 44, 'order_id': '343fbca8-f3e7-4fd4-8f9d-3adc31111095'}
# enviado: {'latitude': 6.229974, 'longitude': -75.564394, 'date': '15/06/2024 01:40:50', 'customer_id': 1386, 'employee_id': 'Employee_142', 'quantity_products': 29, 'order_id': '8e675522-26f5-4a0d-9fad-e305b6cba2b5'}
# enviado: {'latitude': 6.25177, 'longitude': -75.55035, 'date': '15/06/2024 01:40:51', 'customer_id': 1575, 'employee_id': 'Employee_182', 'quantity_products': 21, 'order_id': '9c87153f-3f2a-40a5-929c-d83fa578ea04'}
# enviado: {'latitude': 6.241031, 'longitude': -75.555596, 'date': '15/06/2024 01:40:52', 'customer_id': 1574, 'employee_id': 'Employee_12', 'quantity_products': 40, 'order_id': '4473f016-1d80-411c-a806-21bf0decf7ee'}
# enviado: {'latitude': 6.274, 'longitude': -75.553896, 'date': '15/06/2024 01:40:53', 'customer_id': 1071, 'employee_id': 'Employee_114', 'quantity_products': 4, 'order_id': '5f6ad160-4b0d-49b6-acbb-a175b5de5b98'}
# enviado: {'latitude': 6.241704, 'longitude': -75.544085, 'date': '15/06/2024 01:40:54', 'customer_id': 1743, 'employee_id': 'Employee_172', 'quantity_products': 23, 'order_id': '96ede278-13c6-41e2-9e41-bd5061d06f30'}
# enviado: {'latitude': 6.222883, 'longitude': -75.55123, 'date': '15/06/2024 01:40:55', 'customer_id': 1332, 'employee_id': 'Employee_68', 'quantity_products': 7, 'order_id': '37a2197f-5209-4a80-be6e-787a07e8da3a'}
# enviado: {'latitude': 6.24176, 'longitude': -75.53635, 'date': '15/06/2024 01:40:56', 'customer_id': 1007, 'employee_id': 'Employee_170', 'quantity_products': 37, 'order_id': 'a6938663-98e2-43ea-8323-73aa4e37b1c2'}
# enviado: {'latitude': 6.259229, 'longitude': -75.536218, 'date': '15/06/2024 01:40:57', 'customer_id': 1317, 'employee_id': 'Employee_140', 'quantity_products': 11, 'order_id': '1428e54b-2a80-48f5-9a05-3cd200b822c4'}
# enviado: {'latitude': 6.286593, 'longitude': -75.563808, 'date': '15/06/2024 01:40:58', 'customer_id': 1423, 'employee_id': 'Employee_84', 'quantity_products': 41, 'order_id': '8d3daffd-d6b3-4ef2-9da0-8c8803d000d7'}
# enviado: {'latitude': 6.273539, 'longitude': -75.548488, 'date': '15/06/2024 01:40:59', 'customer_id': 1161, 'employee_id': 'Employee_32', 'quantity_products': 1, 'order_id': '8ab22a4b-f81c-4fcb-81fe-66c8c6fa22db'}
# enviado: {'latitude': 6.296034, 'longitude': -75.552907, 'date': '15/06/2024 01:41:00', 'customer_id': 1876, 'employee_id': 'Employee_128', 'quantity_products': 28, 'order_id': '87fd19c9-8f1d-476f-b23d-64040355b252'}
# enviado: {'latitude': 6.263214, 'longitude': -75.5481, 'date': '15/06/2024 01:41:01', 'customer_id': 1967, 'employee_id': 'Employee_88', 'quantity_products': 47, 'order_id': '6e46b8af-76ef-43d2-9021-49c5c8c2ef2a'}
# enviado: {'latitude': 6.228933, 'longitude': -75.560078, 'date': '15/06/2024 01:41:02', 'customer_id': 1769, 'employee_id': 'Employee_120', 'quantity_products': 50, 'order_id': '5b93e127-e801-454b-ab9e-218216963d4e'}
# enviado: {'latitude': 6.24176, 'longitude': -75.53635, 'date': '15/06/2024 01:41:03', 'customer_id': 1083, 'employee_id': 'Employee_170', 'quantity_products': 3, 'order_id': 'ec439ad6-1f2b-4fcb-8b15-12f3cd466316'}
# enviado: {'latitude': 6.262361, 'longitude': -75.538732, 'date': '15/06/2024 01:41:04', 'customer_id': 1757, 'employee_id': 'Employee_82', 'quantity_products': 14, 'order_id': '57962e97-8f3f-430b-a6f3-675d458cb35d'}
# enviado: {'latitude': 6.256802, 'longitude': -75.536688, 'date': '15/06/2024 01:41:05', 'customer_id': 1518, 'employee_id': 'Employee_16', 'quantity_products': 20, 'order_id': '7277f813-64e1-4ab8-9b01-e5494c5564a8'}
# enviado: {'latitude': 6.270382, 'longitude': -75.530652, 'date': '15/06/2024 01:41:06', 'customer_id': 1419, 'employee_id': 'Employee_178', 'quantity_products': 25, 'order_id': '402af34f-1bef-4c50-96f4-042c98468609'}
# enviado: {'latitude': 6.303074, 'longitude': -75.55662, 'date': '15/06/2024 01:41:07', 'customer_id': 1068, 'employee_id': 'Employee_94', 'quantity_products': 4, 'order_id': 'd2a92024-46f1-4ef1-bd2b-1c74b0bb4dae'}
# enviado: {'latitude': 6.272501, 'longitude': -75.54478, 'date': '15/06/2024 01:41:08', 'customer_id': 1025, 'employee_id': 'Employee_162', 'quantity_products': 3, 'order_id': '0734a6ac-d8ee-40a6-9911-0cb657d9b58d'}
# enviado: {'latitude': 6.279028, 'longitude': -75.550177, 'date': '15/06/2024 01:41:09', 'customer_id': 1180, 'employee_id': 'Employee_150', 'quantity_products': 34, 'order_id': '716d2dc5-6187-4a03-b0d0-2d4e6a8546e2'}
# enviado: {'latitude': 6.223047, 'longitude': -75.551179, 'date': '15/06/2024 01:41:10', 'customer_id': 1368, 'employee_id': 'Employee_126', 'quantity_products': 42, 'order_id': '917066e4-e8f9-4503-a484-e0c0e5ec5489'}
# enviado: {'latitude': 6.286593, 'longitude': -75.563808, 'date': '15/06/2024 01:41:11', 'customer_id': 1397, 'employee_id': 'Employee_84', 'quantity_products': 38, 'order_id': 'b1ef1589-9e7e-4939-adde-8512f9f4495c'}
# enviado: {'latitude': 6.289973, 'longitude': -75.56075, 'date': '15/06/2024 01:41:12', 'customer_id': 1972, 'employee_id': 'Employee_60', 'quantity_products': 40, 'order_id': '14025da1-022c-4d40-9979-c815c5df6e44'}
# enviado: {'latitude': 6.280355, 'longitude': -75.552415, 'date': '15/06/2024 01:41:13', 'customer_id': 1116, 'employee_id': 'Employee_164', 'quantity_products': 31, 'order_id': '906bf22c-b034-4f23-a2a6-155ba9f47d67'}
# enviado: {'latitude': 6.290081, 'longitude': -75.554476, 'date': '15/06/2024 01:41:14', 'customer_id': 1549, 'employee_id': 'Employee_4', 'quantity_products': 20, 'order_id': 'c15c17e3-c406-4eef-bda3-a644f2bcf6b6'}
# enviado: {'latitude': 6.259802, 'longitude': -75.561608, 'date': '15/06/2024 01:41:15', 'customer_id': 1411, 'employee_id': 'Employee_38', 'quantity_products': 14, 'order_id': '2fa4922b-8939-426a-9bd5-5b0b68addb73'}
# enviado: {'latitude': 6.251458, 'longitude': -75.547919, 'date': '15/06/2024 01:41:16', 'customer_id': 1044, 'employee_id': 'Employee_24', 'quantity_products': 19, 'order_id': '89a501b2-a7da-4a07-acee-99f3435ef9b4'}
# enviado: {'latitude': 6.246726, 'longitude': -75.550855, 'date': '15/06/2024 01:41:17', 'customer_id': 1267, 'employee_id': 'Employee_138', 'quantity_products': 28, 'order_id': '22b273cb-23df-4f4a-81a3-afb18e927b7a'}
# enviado: {'latitude': 6.286475, 'longitude': -75.554015, 'date': '15/06/2024 01:41:18', 'customer_id': 1573, 'employee_id': 'Employee_118', 'quantity_products': 2, 'order_id': '06dd34d2-daf3-40d6-9d75-e180e50f8828'}
# enviado: {'latitude': 6.281106, 'longitude': -75.544204, 'date': '15/06/2024 01:41:19', 'customer_id': 1752, 'employee_id': 'Employee_80', 'quantity_products': 3, 'order_id': '8b501c84-e8a4-469c-9451-3e143f2bc365'}
# enviado: {'latitude': 6.280767, 'longitude': -75.554408, 'date': '15/06/2024 01:41:20', 'customer_id': 1145, 'employee_id': 'Employee_6', 'quantity_products': 38, 'order_id': '54ddf806-5882-486d-b4fb-98c1884486a4'}
# enviado: {'latitude': 6.225998, 'longitude': -75.557556, 'date': '15/06/2024 01:41:21', 'customer_id': 1406, 'employee_id': 'Employee_54', 'quantity_products': 8, 'order_id': 'f88099c6-a210-4e17-ba36-36e4cc10b8e5'}
# enviado: {'latitude': 6.227387, 'longitude': -75.539827, 'date': '15/06/2024 01:41:22', 'customer_id': 1004, 'employee_id': 'Employee_78', 'quantity_products': 13, 'order_id': '9484aa91-be9c-4cca-8776-b2b3e86e2a16'}
# enviado: {'latitude': 6.288176, 'longitude': -75.541769, 'date': '15/06/2024 01:41:23', 'customer_id': 1993, 'employee_id': 'Employee_168', 'quantity_products': 34, 'order_id': 'c672d1d8-99a7-4271-9ea4-7bcd4fb5e196'}
# enviado: {'latitude': 6.230513, 'longitude': -75.566217, 'date': '15/06/2024 01:41:24', 'customer_id': 1959, 'employee_id': 'Employee_174', 'quantity_products': 39, 'order_id': 'd5823e58-2afc-44d1-bd2f-a444df778305'}
# enviado: {'latitude': 6.22864, 'longitude': -75.528296, 'date': '15/06/2024 01:41:25', 'customer_id': 1386, 'employee_id': 'Employee_44', 'quantity_products': 5, 'order_id': '08519009-8402-4040-9c6b-0c984b5cdc02'}
# enviado: {'latitude': 6.272501, 'longitude': -75.54478, 'date': '15/06/2024 01:41:26', 'customer_id': 1506, 'employee_id': 'Employee_162', 'quantity_products': 38, 'order_id': 'c943fa30-c7a9-4ba2-ae97-3bb4d7d7ffb2'}
# enviado: {'latitude': 6.241211, 'longitude': -75.530048, 'date': '15/06/2024 01:41:27', 'customer_id': 1505, 'employee_id': 'Employee_180', 'quantity_products': 23, 'order_id': '9837091f-a7a3-44ac-a390-9f745de73596'}
# enviado: {'latitude': 6.241704, 'longitude': -75.544085, 'date': '15/06/2024 01:41:28', 'customer_id': 1799, 'employee_id': 'Employee_172', 'quantity_products': 34, 'order_id': 'a0aff6d4-6867-4a68-83ba-144e453bccbc'}
# enviado: {'latitude': 6.292262, 'longitude': -75.54032, 'date': '15/06/2024 01:41:29', 'customer_id': 1397, 'employee_id': 'Employee_110', 'quantity_products': 19, 'order_id': '1cfd463d-2cfc-40f2-aea2-5d1546f98c04'}
# enviado: {'latitude': 6.276153, 'longitude': -75.561835, 'date': '15/06/2024 01:41:30', 'customer_id': 1439, 'employee_id': 'Employee_22', 'quantity_products': 29, 'order_id': '5ae274e5-788f-4f49-9f19-703826bf37b8'}
# enviado: {'latitude': 6.259802, 'longitude': -75.561608, 'date': '15/06/2024 01:41:31', 'customer_id': 1975, 'employee_id': 'Employee_38', 'quantity_products': 9, 'order_id': 'fccaf26f-e420-4200-b04d-f206e4ddd76e'}
# enviado: {'latitude': 6.280355, 'longitude': -75.552415, 'date': '15/06/2024 01:41:32', 'customer_id': 1844, 'employee_id': 'Employee_164', 'quantity_products': 37, 'order_id': '04f82248-520c-4597-868b-a9d07223d360'}
# enviado: {'latitude': 6.267396, 'longitude': -75.546816, 'date': '15/06/2024 01:41:33', 'customer_id': 1369, 'employee_id': 'Employee_2', 'quantity_products': 20, 'order_id': 'a3aff521-699d-4e80-a687-8b5acd1e62af'}
# enviado: {'latitude': 6.286475, 'longitude': -75.554015, 'date': '15/06/2024 01:41:34', 'customer_id': 1269, 'employee_id': 'Employee_118', 'quantity_products': 45, 'order_id': '8715505b-ec04-419f-ab78-47e5d6770d56'}
# enviado: {'latitude': 6.302737, 'longitude': -75.559773, 'date': '15/06/2024 01:41:35', 'customer_id': 1134, 'employee_id': 'Employee_166', 'quantity_products': 48, 'order_id': 'a332d67c-6c01-41e4-af62-a1d979b62472'}
# enviado: {'latitude': 6.243884, 'longitude': -75.560869, 'date': '15/06/2024 01:41:36', 'customer_id': 1412, 'employee_id': 'Employee_72', 'quantity_products': 20, 'order_id': 'b65030b8-5576-4b14-ba7f-5004bd00ecac'}
# enviado: {'latitude': 6.231145, 'longitude': -75.549267, 'date': '15/06/2024 01:41:37', 'customer_id': 1466, 'employee_id': 'Employee_196', 'quantity_products': 10, 'order_id': '60921b6b-c438-4d61-89a2-0331c372d05c'}
# enviado: {'latitude': 6.239038, 'longitude': -75.533179, 'date': '15/06/2024 01:41:38', 'customer_id': 1722, 'employee_id': 'Employee_46', 'quantity_products': 10, 'order_id': '5dff4c8c-7498-40ce-8e9b-b91c18599d71'}
# enviado: {'latitude': 6.286475, 'longitude': -75.554015, 'date': '15/06/2024 01:41:39', 'customer_id': 1774, 'employee_id': 'Employee_118', 'quantity_products': 3, 'order_id': 'ab45fcc6-8e3e-4f39-8530-fa7dc3a2078b'}
# Deteniendo el servidor...
# Conexión cerrada.
